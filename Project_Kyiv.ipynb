# %% [markdown]
# # OpenStreetMap data wrangling, SQL design and analysis

# %%
# Import required modules
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import csv
import codecs
import cerberus
from time import time
import sqlite3
from pprint import pprint

# %%
# Defone function to count the types of nodes 
def count_tags(filename):
    iter_obj = ET.iterparse(filename)
    d = defaultdict(int)
    for event, element in iter_obj:
        d[element.tag] += 1
    return d

# %%
# Count all types of nodes 
t0=time()
print count_tags('kyiv_ukraine.osm')
print time()-t0
# Out:
# defaultdict(<type 'int'>, {'node': 1401056, 'nd': 1721147, 'bounds': 1, 'member': 79530, 'tag': 618817, 'relation': 7350, 'way': 212674, 'osm': 1})
# 14.8539249897

# %%
# Count 'tags' in 'relations'
t0 = time()
counter = 0 
for _, element in ET.iterparse('kyiv_ukraine.osm'):
    if element.tag == 'relation':
        for tag in element.iter('tag'):
            counter += 1
print time() - t0
# Out:
# 13.4803678989

# %%
# counting phone entries in 'nodes' 'tags'
t0 = time()
counter = 0 
for event, element in ET.iterparse('kyiv_ukraine.osm'):
    if element.tag == 'node':
        for tag in element.iter('tag'):
            if tag.attrib['k'] == 'phone' or tag.attrib['k'] == 'contact:phone':
                counter += 1
print time() - t0
# Out:
# 14.8219199181

# %%
counter
# Out:
# 1474

# %%
# Count phone entries in 'ways' 'tags'
t0 = time()
counter = 0 
for _, element in ET.iterparse('kyiv_ukraine.osm'):
    if element.tag == 'way':
        for tag in element.iter('tag'):
            if tag.attrib['k'] == 'phone' or tag.attrib['k'] == 'contact:phone':
                counter += 1
print time() - t0
# Out:
# 16.6546189785

# %%
counter
# Out:
# 305

# %%
# Audit tag key string types
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        k_value = element.attrib['k']
        if lower.search(k_value):
            keys['lower'] += 1
        elif lower_colon.search(k_value):
            keys['lower_colon'] += 1
        elif problemchars.search(k_value):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
t0=time()
print process_map('kyiv_ukraine.osm')
print time()-t0
# Out:
# {'problemchars': 0, 'lower': 463963, 'other': 717, 'lower_colon': 154137}
# 16.4316270351

# %%
# Extract unique user ids
def get_user(element):
    if element.tag == 'way' or element.tag == 'node':
        if 'uid' in element.attrib.keys():
            uid = element.attrib['uid']
        else:
            uid = 'uid_absent'
    else:
        uid = None
    return uid 


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))
    return users

# %%
t0=time()
user_ids = process_map('kyiv_ukraine.osm')
print time()-t0
# Out:
# 17.741451025

# %%
print 'type:', type(user_ids)
print 'lenght:', len(user_ids)
missing_uids = 0
index_list = []
for i in user_ids:
    if i == 'uid_absent':
        missing_uids += 1
        index_list.append('uid_missing')
    else:
        index_list.append('uid_present')
print 'missing uids:', missing_uids
#print 'missing uid index', index_list.index('uid_missing')
# Out:
# type: <type 'set'>
# lenght: 2288
# missing uids: 1

# %%
# Extract unique user names
def get_user(element):
    if element.tag == 'way' or element.tag == 'node':
        if 'user' in element.attrib.keys():
            user = element.attrib['user']
        else:
            user = 'user_name_absent'
    else:
        user = None
    return user

def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))
    return users

# %%
t0=time()
user_names = process_map('kyiv_ukraine.osm')
print time()-t0
# Out:
# 18.4127700329

# %%
print 'type:', type(user_names)
print 'lenght:', len(user_names)
missing_user_names = 0 
for i in user_names:
    if i == 'user_name_absent':
        missing_user_names += 1
print 'missing user names:', missing_user_names
# Out:
# type: <type 'set'>
# lenght: 2292
# missing user names: 1

# %%
# Extract unique tag k strings
def get_k(element):
    if element.tag == 'tag':
        k = element.attrib['k']
    else:
        k = None
    return k


def process_map(filename):
    ks = set()
    for _, element in ET.iterparse(filename):
        if get_k(element):
            ks.add(get_k(element))
    return ks

# %%
t0 = time()
unique_k_strings = process_map('kyiv_ukraine.osm')
print time() - t0
# Out:
# 15.8906619549

# %%
len(unique_k_strings)
# Out:
# 1153

# %%
# Define function to classify unique key strings into the three types: 
# lower case, lower case with colon, problematic and other
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_string_type(string, keys, lowers, lowers_colon, problematics, others):
    if lower.search(string):
        keys['lower'] += 1
        lowers.append(string)
    elif lower_colon.search(string):
        keys['lower_colon'] += 1
        lowers_colon.append(string)
    elif problemchars.search(string):
        keys['problemchars'] += 1
        problematics.append(string)
    else:
        keys['other'] += 1
        others.append(string)
    return keys, problematics, others

# %%
keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
lowers = []
lowers_colon = []
problematics = []
others = []

for string in unique_k_strings:
    key_string_type(string, keys, lowers, lowers_colon, problematics, others)
    
keys
# Out:
# {'lower': 480, 'lower_colon': 540, 'other': 133, 'problemchars': 0}

# %%
sorted(lowers)
# Out:
# ['_extrude_',
#  '_tessellate_',
#  '_visibility_',
#  'abandoned',
#  'access',
#  'admin_level',
#  'administrative',
#  'advertising',
#  'aerialway',
#  'aeroway',
#  'agricultural',
#  'aircraft',
#  'allotments',
#  'alt_name',
#  'amenity',
#  'animal',
#  'animal_boarding',
#  'animal_keeping',
#  'architect',
#  'area',
#  'artist_name',
#  'artwork_type',
#  'atm',
#  'attraction',
#  'author',
#  'automated',
#  'backcountry',
#  'backrest',
#  'bank',
#  'barbed_tape',
#  'barbed_wire',
#  'barrier',
#  'beauty',
#  'beds',
#  'bench',
#  'bic',
#  'bicycle',
#  'bicycle_parking',
#  'bicycle_road',
#  'bin',
#  'boat',
#  'bollard',
#  'books',
#  'born',
#  'boundary',
#  'boutique',
#  'branch',
#  'brand',
#  'breakfast',
#  'brewery',
#  'bridge',
#  'building',
#  'bunker_type',
#  'bus',
#  'bus_lines',
#  'busway',
#  'button_operated',
#  'cables',
#  'cafe',
#  'canoe',
#  'capacity',
#  'capital',
#  'car',
#  'car_parts',
#  'car_repair',
#  'carpenter',
#  'cash',
#  'cash_in',
#  'castle_type',
#  'cemetery',
#  'charge',
#  'chemist',
#  'childcare',
#  'circuits',
#  'circumference',
#  'clinic',
#  'closest_town',
#  'clothes',
#  'club',
#  'coctails',
#  'collection_times',
#  'colour',
#  'comment',
#  'community',
#  'company',
#  'compartment_post',
#  'condition',
#  'constructed',
#  'construction',
#  'contact_line',
#  'content',
#  'contents',
#  'conveying',
#  'country',
#  'covered',
#  'craft',
#  'created_by',
#  'crop',
#  'crossing',
#  'crossing_ref',
#  'cssh_in',
#  'cuisine',
#  'currency',
#  'cutting',
#  'cycleway',
#  'date',
#  'date_off',
#  'day_off',
#  'day_on',
#  'delivery',
#  'denomination',
#  'denotation',
#  'department',
#  'depth',
#  'desc',
#  'description',
#  'design',
#  'designation',
#  'destination',
#  'diaper',
#  'died',
#  'diet',
#  'diplomatic',
#  'direction',
#  'dispensing',
#  'display',
#  'distance',
#  'disused',
#  'doityourself',
#  'door',
#  'drink',
#  'drinking',
#  'drinking_water',
#  'drinks',
#  'drive_in',
#  'drive_through',
#  'education',
#  'ele',
#  'electrified',
#  'elevator',
#  'email',
#  'embankment',
#  'emergency',
#  'end_date',
#  'entertainment',
#  'entra',
#  'entrance',
#  'escalator',
#  'est_width',
#  'except',
#  'exit',
#  'exit_to',
#  'facebook',
#  'faces',
#  'faculty',
#  'fast_food',
#  'fax',
#  'fee',
#  'female',
#  'fence_type',
#  'fenced',
#  'ffalid',
#  'filling',
#  'fixme',
#  'flag',
#  'flats',
#  'foot',
#  'footway',
#  'ford',
#  'frequency',
#  'from',
#  'function',
#  'funicular',
#  'gas',
#  'gas_insulated',
#  'gauge',
#  'genus',
#  'geonames_id',
#  'golf',
#  'goods',
#  'government',
#  'hairdresser',
#  'handrail',
#  'harbour',
#  'hazard',
#  'hazmat',
#  'hazzard',
#  'headframe',
#  'heading',
#  'healthcare',
#  'height',
#  'heritage',
#  'hgv',
#  'highway',
#  'hiking',
#  'historic',
#  'history',
#  'hoops',
#  'horse',
#  'hov',
#  'iata',
#  'icao',
#  'illegal',
#  'image',
#  'incline',
#  'index',
#  'indoor',
#  'industrial',
#  'information',
#  'inscription',
#  'int_name',
#  'int_network',
#  'int_ref',
#  'interior_decoration',
#  'intermittent',
#  'internet_access',
#  'is_in',
#  'junction',
#  'karaoke',
#  'koatuu',
#  'landuse',
#  'lanes',
#  'lawyer',
#  'layer',
#  'leaf_cycle',
#  'leaf_type',
#  'legal',
#  'leisure',
#  'length',
#  'level',
#  'level_crossing',
#  'levels',
#  'line',
#  'lit',
#  'living_street',
#  'loc_name',
#  'loc_ref',
#  'local_ref',
#  'location',
#  'long_name',
#  'male',
#  'man_made',
#  'manhole',
#  'map_size',
#  'map_type',
#  'material',
#  'maxaxleload',
#  'maxheight',
#  'maxspeed',
#  'maxstay',
#  'maxweight',
#  'maxwidth',
#  'meadow',
#  'megalith_type',
#  'memorial',
#  'microbrewery',
#  'military',
#  'min_height',
#  'mineshaft_type',
#  'mire',
#  'monument',
#  'mooring',
#  'moped',
#  'motor_vehicle',
#  'motorboat',
#  'motorcar',
#  'motorcycle',
#  'mountain_pass',
#  'name',
#  'name_full',
#  'name_official',
#  'name_old',
#  'narrow',
#  'nat_name',
#  'nat_ref',
#  'natural',
#  'nature',
#  'network',
#  'noaddress',
#  'noexit',
#  'noname',
#  'note',
#  'notes',
#  'number',
#  'office',
#  'official_name',
#  'old_name',
#  'old_ref',
#  'oneway',
#  'opening_date',
#  'opening_hours',
#  'oper',
#  'operator',
#  'organic',
#  'outdoor_seating',
#  'oven',
#  'overtaking',
#  'owner',
#  'park_ride',
#  'parking',
#  'passenger_lines',
#  'passing_places',
#  'pawnbroker',
#  'pedestrian',
#  'phone',
#  'pipeline',
#  'place',
#  'place_of_worship',
#  'platforms',
#  'playground',
#  'police',
#  'population',
#  'postal_code',
#  'postal_code_level',
#  'postcode',
#  'power',
#  'power_source',
#  'power_supply',
#  'priority_road',
#  'product',
#  'proposed',
#  'protect_class',
#  'protection_status',
#  'protection_title',
#  'psv',
#  'public_transport',
#  'pump',
#  'quantity',
#  'railway',
#  'ramp',
#  'rank',
#  'rating',
#  'recommended_speed',
#  'recycling',
#  'recycling_type',
#  'ref',
#  'refugee',
#  'reg_name',
#  'reg_ref',
#  'religion',
#  'render',
#  'rental',
#  'repair',
#  'reservation',
#  'residential',
#  'resort',
#  'resource',
#  'restriction',
#  'room',
#  'rooms',
#  'roundtrip',
#  'route',
#  'route_master',
#  'route_ref',
#  'ruins',
#  'sac_scale',
#  'school',
#  'scout',
#  'screen',
#  'seasonal',
#  'seats',
#  'second_hand',
#  'section',
#  'segregated',
#  'self_service',
#  'service',
#  'service_times',
#  'sex',
#  'shape',
#  'share_taxi',
#  'shelter',
#  'shelter_type',
#  'ship',
#  'shop',
#  'short_name',
#  'sidewalk',
#  'sign',
#  'site',
#  'site_type',
#  'ski',
#  'sloped_curb',
#  'smoking',
#  'smoothness',
#  'snowmobile',
#  'social_facility',
#  'source',
#  'source_ref',
#  'species',
#  'sport',
#  'stars',
#  'start_date',
#  'station',
#  'stay',
#  'step_count',
#  'stop_position',
#  'store',
#  'street_cabinet',
#  'structure',
#  'studio',
#  'substance',
#  'substation',
#  'subway',
#  'supervised',
#  'support',
#  'sur',
#  'surface',
#  'surveillance',
#  'symbol',
#  'tactile_paving',
#  'takeaway',
#  'target',
#  'telephone',
#  'text',
#  'thermometer',
#  'ticket',
#  'tickets',
#  'timezone',
#  'to',
#  'tobacco',
#  'toilets',
#  'toll',
#  'tomb',
#  'tou',
#  'tourism',
#  'tourist_bus',
#  'tower',
#  'toys',
#  'track',
#  'tracks',
#  'tracktype',
#  'trade',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_signals',
#  'trail_visibility',
#  'train',
#  'training',
#  'tram',
#  'transformer',
#  'trees',
#  'tributary_of',
#  'triple_tower',
#  'trolley',
#  'trolley_wire',
#  'trolleybus',
#  'tunnel',
#  'two_sided',
#  'type',
#  'undefined',
#  'unisex',
#  'url',
#  'usability',
#  'usage',
#  'valves',
#  'vegetarian',
#  'vehicle',
#  'vending',
#  'via',
#  'visibility',
#  'visible',
#  'voltage',
#  'wall',
#  'waste',
#  'water',
#  'water_well',
#  'waterway',
#  'website',
#  'wetland',
#  'wheelchair',
#  'width',
#  'wifi',
#  'wikidata',
#  'wikimedia_commons',
#  'wikipedia',
#  'wires',
#  'wood',
#  'working',
#  'wpt_description',
#  'wpt_symbol',
#  'zoo']

# %%
sorted(lowers_colon)
# Out:
# ['abandoned:amenity',
#  'abandoned:barrier',
#  'abandoned:building',
#  'abandoned:foutain',
#  'abandoned:highway',
#  'abandoned:historic',
#  'abandoned:landuse',
#  'abandoned:man_made',
#  'abandoned:power',
#  'abandoned:public_transport',
#  'abandoned:railway',
#  'abandoned:shop',
#  'access:conditional',
#  'addr:city',
#  'addr:country',
#  'addr:district',
#  'addr:door',
#  'addr:flats',
#  'addr:floor',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:office',
#  'addr:officenumber',
#  'addr:place',
#  'addr:postcode',
#  'addr:region',
#  'addr:street',
#  'addr:suburb',
#  'addr:unit',
#  'aerialway:access',
#  'aerodrome:type',
#  'alt_name:de',
#  'alt_name:en',
#  'alt_name:eo',
#  'alt_name:es',
#  'alt_name:ru',
#  'alt_name:uk',
#  'alt_name:vi',
#  'animal_keeping:type',
#  'area:highway',
#  'barrier:barbed_tape',
#  'barrier:barbed_wire',
#  'barrier:keypad',
#  'branch:ru',
#  'brand:en',
#  'brand:ru',
#  'brand:uk',
#  'bridge:structure',
#  'building:apartments',
#  'building:cladding',
#  'building:color',
#  'building:colour',
#  'building:height',
#  'building:level',
#  'building:levels',
#  'building:material',
#  'building:min_level',
#  'building:part',
#  'building:parts',
#  'building:roof',
#  'building:use',
#  'camera:mount',
#  'capacity:disabled',
#  'capacity:parent',
#  'capacity:women',
#  'circuits:design',
#  'colour:arrow',
#  'colour:back',
#  'colour:text',
#  'comm:twr',
#  'communication:mobile_phone',
#  'communication:television',
#  'community:gender',
#  'compressed_air:opening_hours',
#  'contact:email',
#  'contact:facebook',
#  'contact:fax',
#  'contact:google_plus',
#  'contact:icq',
#  'contact:phone',
#  'contact:twitter',
#  'contact:website',
#  'crane:mobile',
#  'crane:type',
#  'crossing:barrier',
#  'crossing:bell',
#  'crossing:light',
#  'cycleway:left',
#  'cycleway:right',
#  'demolished:barrier',
#  'demolished:building',
#  'demolished:power',
#  'demolished:railway',
#  'demolished:route',
#  'denomination:ru',
#  'department:en',
#  'description:be',
#  'description:en',
#  'description:ru',
#  'description:uk',
#  'design:ref',
#  'destination:backward',
#  'destination:en',
#  'destination:forward',
#  'destination:lanes',
#  'destroyed:historic',
#  'destroyed:name',
#  'diet:lacto_vegetarian',
#  'diet:vegan',
#  'diet:vegetarian',
#  'display:analog',
#  'disused:amenity',
#  'disused:barrier',
#  'disused:education',
#  'disused:healthcare',
#  'disused:landuse',
#  'disused:leisure',
#  'disused:man_made',
#  'disused:name',
#  'disused:office',
#  'disused:power',
#  'disused:railway',
#  'disused:shop',
#  'disused:sport',
#  'disused:tourism',
#  'door:ellectricallyoperated',
#  'earthquake:damage',
#  'esr:code',
#  'esr:user',
#  'exit_to:en',
#  'express:code',
#  'express:name',
#  'faculty:en',
#  'fence:height',
#  'fence:material',
#  'fence:type',
#  'fire_hydrant:count',
#  'fire_hydrant:diameter',
#  'fire_hydrant:position',
#  'fire_hydrant:type',
#  'fuel:biodiesel',
#  'fuel:biogas',
#  'fuel:cng',
#  'fuel:diesel',
#  'fuel:discount',
#  'fuel:electricity',
#  'fuel:lpg',
#  'generator:method',
#  'generator:source',
#  'genus:en',
#  'genus:ua',
#  'gvr:code',
#  'handrail:center',
#  'handrail:left',
#  'handrail:right',
#  'hazard:conditional',
#  'hazmat:conditional',
#  'health_facility:type',
#  'healthcare:speciality',
#  'height:class',
#  'height:unit',
#  'heritage:name',
#  'heritage:ref',
#  'heritage:short_name',
#  'hgv:conditional',
#  'highway:backward',
#  'highway:forward',
#  'historic:epoch',
#  'historic:period',
#  'inscription:en',
#  'inscription:ru',
#  'inscription:uk',
#  'internet_access:access',
#  'internet_access:fee',
#  'is_in:continent',
#  'is_in:country',
#  'is_in:country_code',
#  'lanes:backward',
#  'lanes:extra',
#  'lanes:forward',
#  'lengths:left',
#  'lengths:right',
#  'lift_gate:type',
#  'loc_name:ru',
#  'location:transition',
#  'long_name:en',
#  'mast:type',
#  'maxspeed:conditional',
#  'maxspeed:forward',
#  'maxspeed:practical',
#  'medical_system:western',
#  'memorial:type',
#  'missing:historic',
#  'monitoring:temperature',
#  'monitoring:weather',
#  'mtb:scale',
#  'mtb:type',
#  'name:ab',
#  'name:ace',
#  'name:af',
#  'name:als',
#  'name:am',
#  'name:an',
#  'name:ang',
#  'name:ar',
#  'name:arc',
#  'name:arz',
#  'name:ast',
#  'name:az',
#  'name:ba',
#  'name:bar',
#  'name:bcl',
#  'name:be',
#  'name:bg',
#  'name:bi',
#  'name:bn',
#  'name:bo',
#  'name:bpy',
#  'name:br',
#  'name:bs',
#  'name:bxr',
#  'name:ca',
#  'name:cdo',
#  'name:ce',
#  'name:ceb',
#  'name:chr',
#  'name:chy',
#  'name:ckb',
#  'name:crh',
#  'name:cs',
#  'name:csb',
#  'name:cu',
#  'name:cv',
#  'name:cy',
#  'name:da',
#  'name:de',
#  'name:diq',
#  'name:dsb',
#  'name:dv',
#  'name:ee',
#  'name:el',
#  'name:en',
#  'name:eo',
#  'name:es',
#  'name:esr',
#  'name:et',
#  'name:eu',
#  'name:ext',
#  'name:fa',
#  'name:fi',
#  'name:fo',
#  'name:fr',
#  'name:frp',
#  'name:frr',
#  'name:full',
#  'name:fy',
#  'name:ga',
#  'name:gag',
#  'name:gan',
#  'name:gd',
#  'name:gl',
#  'name:gn',
#  'name:gu',
#  'name:gv',
#  'name:hak',
#  'name:haw',
#  'name:he',
#  'name:hi',
#  'name:hif',
#  'name:hr',
#  'name:hsb',
#  'name:ht',
#  'name:hu',
#  'name:hy',
#  'name:ia',
#  'name:id',
#  'name:ie',
#  'name:ig',
#  'name:ilo',
#  'name:io',
#  'name:is',
#  'name:it',
#  'name:ja',
#  'name:jbo',
#  'name:jv',
#  'name:ka',
#  'name:kaa',
#  'name:kab',
#  'name:kbd',
#  'name:kg',
#  'name:kk',
#  'name:kl',
#  'name:km',
#  'name:kn',
#  'name:ko',
#  'name:koi',
#  'name:krc',
#  'name:ku',
#  'name:kv',
#  'name:kw',
#  'name:ky',
#  'name:la',
#  'name:lad',
#  'name:lb',
#  'name:lez',
#  'name:li',
#  'name:lij',
#  'name:lmo',
#  'name:ln',
#  'name:lt',
#  'name:ltg',
#  'name:lv',
#  'name:mdf',
#  'name:mg',
#  'name:mhr',
#  'name:mi',
#  'name:mk',
#  'name:ml',
#  'name:mn',
#  'name:mr',
#  'name:mrj',
#  'name:ms',
#  'name:mt',
#  'name:mwl',
#  'name:my',
#  'name:myv',
#  'name:mzn',
#  'name:na',
#  'name:nah',
#  'name:nap',
#  'name:nds',
#  'name:ne',
#  'name:new',
#  'name:nl',
#  'name:nn',
#  'name:no',
#  'name:nov',
#  'name:nrm',
#  'name:nv',
#  'name:oc',
#  'name:or',
#  'name:os',
#  'name:pa',
#  'name:pam',
#  'name:pap',
#  'name:pcd',
#  'name:pih',
#  'name:pl',
#  'name:pms',
#  'name:pnb',
#  'name:pnt',
#  'name:prefix',
#  'name:ps',
#  'name:pt',
#  'name:qu',
#  'name:rm',
#  'name:rmy',
#  'name:ro',
#  'name:ru',
#  'name:rue',
#  'name:rw',
#  'name:sah',
#  'name:sc',
#  'name:scn',
#  'name:sco',
#  'name:se',
#  'name:sh',
#  'name:simple',
#  'name:sk',
#  'name:sl',
#  'name:sm',
#  'name:sn',
#  'name:so',
#  'name:sq',
#  'name:sr',
#  'name:ss',
#  'name:stq',
#  'name:su',
#  'name:sv',
#  'name:sw',
#  'name:szl',
#  'name:ta',
#  'name:te',
#  'name:tg',
#  'name:th',
#  'name:tk',
#  'name:tl',
#  'name:tpi',
#  'name:tr',
#  'name:ts',
#  'name:tt',
#  'name:tum',
#  'name:tw',
#  'name:tzl',
#  'name:ua',
#  'name:udm',
#  'name:ug',
#  'name:uk',
#  'name:ur',
#  'name:uz',
#  'name:vec',
#  'name:vep',
#  'name:vi',
#  'name:vls',
#  'name:vo',
#  'name:wa',
#  'name:war',
#  'name:wo',
#  'name:xal',
#  'name:xmf',
#  'name:yi',
#  'name:yo',
#  'name:zea',
#  'name:zh',
#  'name:zu',
#  'note:en',
#  'note:ru',
#  'note:uk',
#  'observatory:type',
#  'official_name:de',
#  'official_name:en',
#  'official_name:ru',
#  'old:name',
#  'old_name:de',
#  'old_name:en',
#  'old_name:ru',
#  'old_name:uk',
#  'old_name:vi',
#  'oneway:bicycle',
#  'oneway:conditional',
#  'oneway:moped',
#  'oneway:psv',
#  'opening_hours:url',
#  'openplaques:id',
#  'operator:en',
#  'operator:ru',
#  'operator:uk',
#  'parking:primary_usage',
#  'payment:bitcoin',
#  'payment:cards',
#  'payment:cash',
#  'payment:coins',
#  'payment:credit_cards',
#  'payment:cryptocurrencies',
#  'payment:debit_cards',
#  'payment:electronic_purses',
#  'payment:laser',
#  'payment:litecoin',
#  'payment:maestro',
#  'payment:mastercard',
#  'payment:notes',
#  'payment:telephone_cards',
#  'payment:visa',
#  'payment:visa_debit',
#  'payment:visa_electron',
#  'phone:mobile',
#  'pipeline:quantity',
#  'piste:difficulty',
#  'piste:type',
#  'plant:method',
#  'plant:source',
#  'post_box:type',
#  'proposed:amenity',
#  'public_transport:version',
#  'railway:track_ref',
#  'railway:turnout_side',
#  'ramp:bicycle',
#  'ramp:luggage',
#  'ramp:stroller',
#  'ramp:wheelchair',
#  'recycling:batteries',
#  'recycling:cans',
#  'recycling:cardboard',
#  'recycling:cartons',
#  'recycling:clothes',
#  'recycling:glass',
#  'recycling:glass_bottles',
#  'recycling:green_waste',
#  'recycling:metal',
#  'recycling:paper',
#  'recycling:paper_packaging',
#  'recycling:plastic',
#  'recycling:plastic_bottles',
#  'recycling:plastic_caps',
#  'recycling:plastic_packaging',
#  'recycling:scrap_metal',
#  'ref:addr',
#  'ref:en',
#  'ref:ru',
#  'removed:tourism',
#  'retaining_wall:material',
#  'roof:angle',
#  'roof:colour',
#  'roof:height',
#  'roof:levels',
#  'roof:material',
#  'roof:orientation',
#  'roof:ridge',
#  'roof:shape',
#  'short_name:de',
#  'short_name:en',
#  'short_name:ru',
#  'short_name:uk',
#  'social_facility:for',
#  'source:abandoned',
#  'source:addr',
#  'source:date',
#  'source:maxspeed',
#  'source:name',
#  'subject:wikipedia',
#  'surveillance:type',
#  'survey:date',
#  'swing_gate:type',
#  'theatre:genre',
#  'tickets:train',
#  'tiger:name_type',
#  'toilets:disposal',
#  'toilets:position',
#  'toilets:wheelchair',
#  'toll:bicycle',
#  'toll:foot',
#  'tower:type',
#  'traffic_signals:direction',
#  'traffic_signals:sound',
#  'turn:lanes',
#  'type:sewage',
#  'vehicle:conditional',
#  'wall:material',
#  'wall:type',
#  'was:building',
#  'wheelchair:description',
#  'wikipedia:be',
#  'wikipedia:de',
#  'wikipedia:en',
#  'wikipedia:pl',
#  'wikipedia:ru',
#  'wikipedia:uk',
#  'wood:age',
#  'zone:maxspeed']

# %%
sorted(others)
# Out:
# ['CEMT',
#  'ISO3166-1',
#  'ISO3166-1:alpha2',
#  'ISO3166-1:alpha3',
#  'ISO3166-1:numeric',
#  'ISO3166-2',
#  '_Name_',
#  'addr:city:en',
#  'addr:housename:de',
#  'addr:housenumber_1',
#  'addr:interpolation_1',
#  'addr:street:en',
#  'addr:street_1',
#  'amenity_1',
#  'amenity_2',
#  'artwork:3D',
#  'associatedStreet',
#  'bridge_1',
#  'building:levels:underground',
#  'building:parts:horizontal',
#  'building:parts:vertical',
#  'building:roof:shape',
#  'building_1',
#  'bunker_type_1',
#  'cinema:3D',
#  'compartment:NW',
#  'currency:EUR',
#  'currency:RUB',
#  'currency:RUR',
#  'currency:UAH',
#  'currency:USD',
#  'demolished:piste:type',
#  'depot:vehicle:tram',
#  'description_1',
#  'destination:lang:en:backward',
#  'destination:lang:en:lanes',
#  'destroyed:name:ru',
#  'destroyed:name:uk',
#  'disused:name:ru',
#  'disused:name:uk',
#  'drink_1',
#  'e-road:class',
#  'fixme:building:part',
#  'fixme:building:parts',
#  'fuel:GTL_diesel',
#  'fuel:HGV_diesel',
#  'fuel:e10',
#  'fuel:e85',
#  'fuel:octane_100',
#  'fuel:octane_80',
#  'fuel:octane_91',
#  'fuel:octane_92',
#  'fuel:octane_95',
#  'fuel:octane_98',
#  'generator:output:electricity',
#  'generator:output:hot_water',
#  'generator:output:steam',
#  'highway_1',
#  'internet_access:wlan:key',
#  'lanes:psv:backward',
#  'lanes:psv:forward',
#  'lawyer:FR',
#  'leisure_1',
#  'loc_name_1',
#  'mtb:scale:imba',
#  'mtb:scale:uphill',
#  'name:bat-smg',
#  'name:be-tarask',
#  'name:cbk-zam',
#  'name:en_1',
#  'name:fiu-vro',
#  'name:nds-nl',
#  'name:roa-rup',
#  'name:roa-tara',
#  'name:ru-Latn',
#  'name:ru_1',
#  'name:sr-Latn',
#  'name:uk-Latn',
#  'name:uk_1',
#  'name:zh-classical',
#  'name:zh-min-nan',
#  'name:zh-yue',
#  u'name:\u043a\u0433',
#  'name_1',
#  'name_2',
#  'name_3',
#  'name_4',
#  'naptan:AtcoCode',
#  'naptan:Bearing',
#  'natural_1',
#  'parking:condition:both',
#  'parking:condition:right',
#  'parking:lane:both',
#  'parking:lane:right',
#  'parking:lane:side',
#  'phone_1',
#  'phone_2',
#  'phone_3',
#  'place:1800-1900',
#  'place_1',
#  'plant:output:electricity',
#  'plant:output:hot_water',
#  'playground_1',
#  'porog1',
#  'porog2',
#  'power:output:hot_water',
#  'railway:ref:DB',
#  'railway:switch:electric',
#  'ref_1',
#  'service:bicycle:chain_tool',
#  'service:bicycle:diy',
#  'service:bicycle:pump',
#  'service:bicycle:rental',
#  'service:bicycle:repair',
#  'service:bicycle:retail',
#  'service:bicycle:second_hand',
#  'service:bike:parts',
#  'shop_1',
#  'shop_2',
#  'sidewalk:both:surface',
#  'sidewalk:left:surface',
#  'sidewalk:left:width',
#  'sidewalk:right:surface',
#  'sport_1',
#  'surface_1',
#  'turn:lanes:backward',
#  'turn:lanes:forward',
#  'type_1',
#  'website_1',
#  'wikipedia_1',
#  u'\u041c\u0435\u0431\u0435\u043b\u044c',
#  u'\u041f\u0435\u0440\u0435\u0442\u044f\u0436\u043a\u0430',
#  u'\u0420\u0435\u043c\u043e\u043d\u0442']

# %%
# Find values listed under 'addr:street:en' and 'addr:street_1'
t0 = time()
streets_under_alt_k = []
for _, element in ET.iterparse('kyiv_ukraine.osm'):
    if element.tag == 'tag':
        if element.attrib['k'] == 'addr:street:en' or element.attrib['k'] == 'addr:street_1':
            streets_under_alt_k.append(element.attrib['v'])
print time() - t0
for i in streets_under_alt_k:
    print i
# Out:
# 15.197660923
# Petra Hryhorenka Avenue
# Saksahanskoho Street
# Kiltseva Road
# 15 км
# Фрунзе
# Petra Hryhorenka Avenue
# Revutskogo
# Saksahanskoho
# Dragomanova
# Ирпенская улица

# %%
'''Auditing phone numbers'''

'''def audit_phone_number(phone_number)'''

#regex_normal = re.compile(r'(\+?38)?\W*(0?\W*\d{2})?\W*(\d\W*\d\W*\d)\W*(\d{2})\W*(\d{2})')
#regex_normal = re.compile(r'(\+?38)?\W*(0?\d{2})?\W*(\d\d\d)\W*(\d{2})\W*(\d{2})')
#regex_normal = re.compile(r'(38)?\W*(0)?\W*(\d{2})?\W*(\d{3})\W*(\d{2})\W*(\d{2})')
#regex_38 = re.compile(r'(\+?)(38)\W*(0)\W*(\d{2})\W*(\d{3})\W*(\d{2})\W*(\d{2})')
regex_38 = re.compile(r'(3)\W*(8)\W*(0)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
#regex_0xx = re.compile(r'^\W?(0\d{2})\W*(\d{3})\W*(\d{2})\W*(\d{2})\b')
regex_0xx = re.compile(r'^\W?(0)\W*(\d{2})\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
#regex_800 = re.compile(r'\d\W800\W\d{3}\W\d{3}')
regex_800 = re.compile(r'^(0|8)\W*(800)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
regex_xxx = re.compile(r'^(\d{3})\W*(\d{2})\W*(\d{2})$')

# %%
ph = r'0800500-609'
m = regex_800.findall(ph)

# %%
m
# Out:
# [('0', '800', '5', '0', '0', '6', '0', '9')]

# %%
# Count regex matches 
t0 = time()
counter = {'w38':0, 'w800':0, 'w0xx':0, 'wxxx':0, 'problematic':0}
w38 = []
w800 = []
w0xx = []
wxxx = []
problematics = []
for event, elem in ET.iterparse('kyiv_ukraine.osm'):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone" or tag.attrib['k'] == "contact:phone":
                if regex_38.search(tag.attrib['v']):
                    counter['w38'] += 1
                    w38.append(tag.attrib['v'])
                elif regex_800.search(tag.attrib['v']):
                    counter['w800'] += 1
                    w800.append(tag.attrib['v'])
                elif regex_0xx.search(tag.attrib['v']):
                    counter['w0xx'] += 1
                    w0xx.append(tag.attrib['v'])
                elif regex_xxx.search(tag.attrib['v']):
                    counter['wxxx'] += 1
                    wxxx.append(tag.attrib['v'])
                else:
                    counter['problematic'] += 1
                    problematics.append(tag.attrib['v'])
print time() - t0
# Out:
# 17.2634048462

# %%
print counter
# Out:
# {'wxxx': 21, 'w38': 1393, 'problematic': 36, 'w0xx': 292, 'w800': 37}

# %%
sorted(problematics)
# Out:
# ['(44)4247431',
#  '+1 347 868 0740',
#  '+3-044-257-20-97',
#  '+3-8-044-446-77e-70',
#  '+30 (44) 536-99-06; +30 (44) 536-99-08; +30 (44) 536-99-07',
#  '+3044 401-42-94',
#  '+30442556013',
#  '+38 44 2784864',
#  '+38 44 425 03 98',
#  '+380 (044) 235-73-82',
#  '+380 (044) 275-33-00',
#  '+380 (044) 360 02 09',
#  '+380 (044) 486-18-08',
#  '+380 (067) 912-20-66',
#  '+380 44 01010',
#  '+380 9905577327',
#  '+380(044) 528-30-47',
#  '+380-044-4172526',
#  '+3800675055958',
#  '+3804118875',
#  '+38986073213',
#  '+39 044 5939575',
#  '+800 1800 1800',
#  '044526',
#  '08005005000',
#  '102',
#  '234-55-83;234-05-88;235-23-21',
#  '287-32-11 066-563-57-29',
#  '2870711,2870020',
#  '2876149,2876216',
#  '4-60-85',
#  '5-74-41',
#  '67 401 21 66, 044 287 5252',
#  '8097-331-17-93',
#  '88003000500',
#  u'\u0420\u0435\u0433\u0438\u0441\u0442\u0440\u0430\u0442\u0443\u0440\u0430 - (044) 408-03-41, \u0412\u044b\u0437\u043e\u0432 \u0432\u0440\u0430\u0447\u0430 - (044) 408-74-40, \u041d\u0435\u043e\u0442\u043b\u043e\u0436\u043d\u0430\u044f \u043f\u043e\u043c\u043e\u0449\u044c - (044) 497-60-61']

# %%
phone_mapping = {
    '(44)4247431' : '+38-044-424-7431',
     '+1 347 868 0740' : '+1-347-868-0740', 
     '+3-044-257-20-97' : '+38-044-257-2097',
     '+3-8-044-446-77e-70' : '+38-044-446-7770',
     '+30 (44) 536-99-06; +30 (44) 536-99-08; +30 (44) 536-99-07' : '+38-044-536-9906', 
     '+3044 401-42-94' : '+38-044-401-4294',
     '+30442556013' : '+38-044-255-6013', 
     '+38 44 2784864' : '+38-044-278-4864', 
     '+38 44 425 03 98' : '+38-044-4250-0398', 
     '+380 (044) 235-73-82' : '+38-044-235-7382', 
     '+380 (044) 275-33-00' : '+38-044-275-3300', 
     '+380 (044) 360 02 09' : '+38-044-360 0209', 
     '+380 (044) 486-18-08' : '+38-044-486-1808', 
     '+380 (067) 912-20-66' : '+38 067 912-2066', 
     '+380 44 01010' : 'ERRONEUS', 
     '+380 9905577327' : '+38-099-055-77327', 
     '+380(044) 528-30-47' : '+38-044-528-3047',
     '+380-044-4172526' : '+38-044-417-2526', 
     '+3800675055958' : '+38-067-505-5958', 
     '+3804118875' : 'ERRONEOUS', 
     '+38986073213' : '+38-098-607-3213',
     '+39 044 5939575' : '+38-044-593-9575',
     '+800 1800 1800' : 'ERRONEUOUS', 
     '044526' : 'ERRONEOUS', 
     '08005005000' : 'ERRONEOUS', 
     '102' : ' ERRONEOUS', 
     '234-55-83;234-05-88;235-23-21' : '+38-044-234-5583', 
     '287-32-11 066-563-57-29' : '38-044-287-3211', 
     '2870711,2870020' : '+38-044-287-0711', 
     '2876149,2876216' : '+38-044-287-6149', 
     '4-60-85' : 'ERRONEOUS', 
     '5-74-41' : 'ERRONEOUS',
     '67 401 21 66, 044 287 5252' : '+38-067-401-2166', 
     '8097-331-17-93' : '+38-097-331-1793', 
     '88003000500' : 'ERRONEOUS', 
 u'\u0420\u0435\u0433\u0438\u0441\u0442\u0440\u0430\u0442\u0443\u0440\u0430 - (044) 408-03-41, \u0412\u044b\u0437\u043e\u0432 \u0432\u0440\u0430\u0447\u0430 - (044) 408-74-40, \u041d\u0435\u043e\u0442\u043b\u043e\u0436\u043d\u0430\u044f \u043f\u043e\u043c\u043e\u0449\u044c - (044) 497-60-61'
: '38-044-408-0341'}

# %%
phone_mapping['67 401 21 66, 044 287 5252']
# Out:
# '+38-067-401-2166'

# %%
# Define function to standardize phone numbers
def standardize_phone(number, phone_mapping):
    stnd = ''
    if regex_38.search(number):
        m = regex_38.search(number)
        stnd = stnd + '+' + m.group(1) + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8) + '-' + m.group(9) + m.group(10) + m.group(11) + m.group(12)
    elif regex_800.search(number):
        m = regex_800.search(number)
        stnd = stnd + m.group(1) + '-' + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8)
    elif regex_0xx.search(number):
        m = regex_0xx.search(number)
        stnd = stnd + '+38-' + m.group(1) + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8) + m.group(9) 
    elif regex_xxx.search(number):
        m = regex_xxx.search(number)
        stnd = stnd + '+38-044-' + m.group(1) + '-' + m.group(2) + '-' + m.group(3)
    else:
        stnd = phone_mapping[number]
    return stnd

# %%
standardize_phone('0 (44) 52026 08', phone_mapping)
# Out:
# '+38-044-520-2608'

# %%
# Count phones number entries in 'node' and 'way' 'tags'
t0 = time()
counter = 0 
for event, elem in ET.iterparse('kyiv_ukraine.osm'):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone":
                counter += 1
print time() - t0
# Out:
# 17.3097550869

# %%
counter
# Out:
# 1544

# %%
# Test standardize function
t0 = time()
phone_list = [] 
for event, elem in ET.iterparse('kyiv_ukraine.osm'):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone":
                phone_list.append(standardize_phone(tag.attrib['v'], phone_mapping))
print time() - t0
# Out:
# 16.7216579914

# %%
len(phone_list)
# Out:
# 1544

# %%
phone_list
# Out:
# ['+38-044-501-3297',
#  '0-800-501-505',
#  '+38-093-977-5883',
#  '+38-044-247-4314',
#  '+38-044-287-2000',
#  '+38-044-529-6193',
#  '+38-044-254-3610',
#  '+38-044-288-9775',
#  '+38-044-285-5625',
#  '+38-044-354-0535',
#  '+38-044-257-9429',
#  '+38-044-234-3380',
#  '+38-068-850-6060',
#  '+38-044-468-2298',
#  '+38-044-285-6550',
#  '+38-044-275-3688',
#  '+38-044-585-2728',
#  '+38-044-258-0554',
#  '+38-044-287-1002',
#  '+38-044-234-7423',
#  '+38-044-289-2020',
#  '+38-044-289-33-22',
#  '+38-044-284-4011',
#  '+38-044-486-6336',
#  '+38-080-030-1707',
#  '+38-044-257-5594',
#  '+38-067-443-6565',
#  '+38-044-206-0562',
#  '+38-044-331-5781',
#  '+38-044-567-9196',
#  '+38-099-010-9993',
#  '+38-044-257-8640',
#  '+38-044-259-7672',
#  '+38-044-531-9400',
#  '+38-044-288-8727',
#  'ERRONEOUS',
#  '+38-044-464-4734',
#  '+38-044-288-5225',
#  '+38-044-567-6768',
#  '+38-044-456-0243',
#  '+38-044-569-19-09',
#  '+38-044-569-19-09',
#  '+38-044-500-5000',
#  '+38-044-234-5678',
#  '+38-044-461-8788',
#  '+38-044-417-3190',
#  '+38-044-287-0711',
#  '+38-044-254-2024',
#  '+38-044-490-2760',
#  '+38-044-280-1119',
#  '+38-044-290-9803',
#  '+38-044-280-5396',
#  '+38-044-278-0936',
#  '+38-044-541-02-32',
#  '+38-044-377-5086',
#  '+38-044-384-2804',
#  '0-800-500-990',
#  '+38-044-238-7363',
#  '+38-044-593-1203',
#  '+38-067-249-5870',
#  '+38-093-880-3344',
#  '+38-044-228-6765',
#  '0-800-500-512',
#  '+38-044-228-4760',
#  '+38-044-227-7011',
#  '+38-066-548-8995',
#  '+38-044-248-1081',
#  '+38-044-467-7629',
#  '+38-044-579-23-36',
#  '+38-066-974-8009',
#  '+38-050-771-3357',
#  '+38-044-457-6764',
#  '+38-050-771-3357',
#  '+38-044-430-0602',
#  '+38-044-425-5166',
#  '+38-044-227-1581',
#  '+38-044-237-7167',
#  '+38-044-290-7588',
#  '+38-067-964-6428',
#  '+38-044-383-7322',
#  '+38-097-902-2262',
#  '+38-044-277-7883',
#  '+38-067-220-7461',
#  '+38-044-277-7935',
#  '+38-044-206-9787',
#  '+38-044-483-8900',
#  '+38-044-593-9052',
#  '+38-044-411-1588',
#  '+38-045-714-1349',
#  '+38-044-423-8687',
#  '+38-093-788-4788',
#  '+38-044-338-2797',
#  '+38-096-123-3563',
#  '+38-044-227-9432',
#  '+38-063-630-6699',
#  '+38-050-383-9817',
#  '+38-044-569-5646',
#  ...]

# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
street_type_re = re.compile(r'\b\S+\.?$', re.UNICODE | re.IGNORECASE)


# expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            # "Trail", "Parkway", "Commons"]
    
expected =['вулиця'.decode('utf-8'), 'бульвар'.decode('utf-8'), 'тупик'.decode('utf-8'), 'проїзд'.decode('utf-8'),
          'проспект'.decode('utf-8'), 'алея'.decode('utf-8'), 'шосе'.decode('utf-8'), 'набережна'.decode('utf-8'),
          'узвіз'.decode('utf-8'), 'дорога'.decode('utf-8'), 'провулок'.decode('utf-8'), 'площа'.decode('utf-8'),
          'шоссе'.decode('utf-8')]

# UPDATE THIS VARIABLE
street_mapping = { 'ул.'.decode('utf-8') : 'вулиця'.decode('utf-8'),
           'ул'.decode('utf-8') : 'вулиця'.decode('utf-8'),
           'пл.'.decode('utf-8') : 'площа'.decode('utf-8'), 
           'шоссе-2'.decode('utf-8') : 'шоссе'.decode('utf-8'),
           'улица'.decode('utf-8') : 'вулиця'.decode('utf-8')
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    # osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osmfile, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    # osm_file.close()
    return street_types


def update_name(name, street_mapping):
    m = street_type_re.search(name)
    if m and m.group() in street_mapping:
        name = re.sub(street_type_re, street_mapping[m.group()], name)
    return name

"""
for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            if name == "West Lexington St.":
                ass. better_name == "West Lexington Street"
            if name == "Baldwin Rd.":
                ass. better_name == "Baldwin Road"
"""
# Out:
# '\nfor st_type, ways in st_types.iteritems():\n        for name in ways:\n            better_name = update_name(name, mapping)\n            print name, "=>", better_name\n            if name == "West Lexington St.":\n                ass. better_name == "West Lexington Street"\n            if name == "Baldwin Rd.":\n                ass. better_name == "Baldwin Road"\n'

# %%
print update_name('Парковая ул.'.decode('utf-8'), street_mapping)
# Out:
# Парковая вулиця

# %%
t0 = time()
anomalous_street_names = audit('kyiv_ukraine.osm')
print time() - t0
# Out:
# 17.513010025

# %%
for i in anomalous_street_names.keys():
    print i
# Out:
# Паширова
# Ленінградська
# Лесная)
# Парковая
# Багірова
# М.Хвильового
# Градинська
# Заболотного
# Дімітрова
# Академічна
# Лінія
# 8
# ул.
# прикордонна
# Березова
# Берковецкая
# Золотоворітська
# Северинівська
# Карьерная
# Лугова
# Вітянська
# Глушкова
# Лучистая
# Рудыковская
# Сковороди
# Набережная
# Червоноармійська
# Ленинградская
# Дзержинського
# Кільцева
# Вовчка
# Тіниста
# Виставкова
# Сталинграда
# Лес
# шлях
# Паркова
# гоголя
# Колгоспний
# Кошова
# Сагайдачного
# Озерна
# Драйзера
# Лисенка
# шевченка
# Г.Сковороди
# Садова
# Михайлівська
# Бурки
# Центральная(Ленина)
# Стрільців
# Окружная
# Богатирська
# пл.
# городок
# Набережно-Корчеватская
# Героїв
# пер
# Комарова
# Компресорна
# мікрорайон
# Грушевского
# Осенняя
# Gladkivska
# ул
# Лебединская
# Покровська
# Петлюри
# Орача
# вулиця/Петропавлівська
# Лютнева
# Антонова
# Варшавська
# Нахимова
# Заміський
# 11
# 10
# Электротехническая
# шоссе-2
# Ломоносова
# ул.Дзержинского
# Аркадия
# лютнева
# Шевченка
# Яблунська
# zhylianskaya
# В.Непопа
# В.Лобановского
# Полевая
# Народная
# Лісовий
# переулок
# Київська
# Озерная
# Прикордонна
# Артема
# народів
# Майдану
# 1
# Дніпра
# Бальзака
# Київ-Чернігів
# Леніна
# Соцмістечко
# Весильна
# Варшавская
# Маяковського
# Першотравнева
# улица
# Дачи
# Незалежності
# Ковшевацкого
# Москаленко
# Нова
# Тернопольская
# Стельмаха
# урочище
# Хмельницького
# Словянська

# %%
# Create a set of (unique) streets
t0 = time()
kyiv_streets = set()
for _, elem in ET.iterparse('kyiv_ukraine.osm'):
    if elem.tag == 'tag' and is_street_name(elem):
        kyiv_streets.add(elem.attrib['v'])
print time() - t0
# Out:
# 13.465720892

# %%
len(kyiv_streets)
# Out:
# 1646

# %%
for street in sorted(kyiv_streets):
    print street
# Out:
# 1-а Лінія вулиця
# 1-а Піщана вулиця
# 1-го Травня вулиця
# 1-й Червоний провулок
# 10
# 10-а Лінія
# 10-а Лінія вулиця
# 11-а Лінія
# 11-а Лінія вулиця
# 12-а Лінія вулиця
# 12-а Садова вулиця
# 13-а Лінія вулиця
# 14-а Лінія вулиця
# 15-а Лінія вулиця
# 16-а Лінія вулиця
# 17-а Лінія вулиця
# 18-а Лінія вулиця
# 19-а Лінія вулиця
# 2-а Лінія вулиця
# 2-а Нова вулиця
# 2-а Піщана вулиця
# 2-й Маршака провулок
# 2-й Північний тупик
# 20-а Лінія вулиця
# 20-а Садова вулиця
# 21-а Лінія вулиця
# 22-а Лінія вулиця
# 23-я Лінія вулиця
# 23-я Лінія провулок
# 23-я Садова вулиця
# 24-а Лінія вулиця
# 25-а Лінія вулиця
# 255, Київська вулиця
# 26-а Лінія вулиця
# 27-а Лінія вулиця
# 28 км + 900 м. автодороги Київ-Чернігів
# 28-а Лінія вулиця
# 29-а Лінія вулиця
# 3-я Лінія вулиця
# 30-а Лінія вулиця
# 31-а Лінія вулиця
# 32-а Лінія вулиця
# 33-я Лінія вулиця
# 34-а Лінія вулиця
# 35-а Лінія вулиця
# 36-а Лінія вулиця
# 37-а Лінія вулиця
# 38-а Лінія вулиця
# 39-а Лінія вулиця
# 4-а Лінія вулиця
# 40 років Жовтня вулиця
# 40-а Лінія вулиця
# 42-а Садова вулиця
# 5-а Лінія вулиця
# 5-а Садова вулиця
# 50 років СРСР вулиця
# 51-й км Санкт-Петербурзького шосе
# 58-а Садова вулиця
# 6-а Лінія вулиця
# 7-а Лінія вулиця
# 7-а Центральна вулиця
# 7-го Жовтня вулиця
# 8-а Лінія вулиця
# 8-а Садова вулиця
# 8-го Березня вулиця
# 9-а Лінія вулиця
# Gladkivska
# zhylianskaya
# Євгена Гуцала провулок
# Євгена Коновальця вулиця
# Євгена Маланюка вулиця
# Євгена Сверстюка вулиця
# Євгена Харченка вулиця
# Європейська вулиця
# Єлізавети Чавдар вулиця
# Єреванська вулиця
# Єрощенка вулиця
# Івана Їжакевича вулиця
# Івана Гонти вулиця
# Івана Дяченка вулиця
# Івана Кавалерідзе вулиця
# Івана Крамського вулиця
# Івана Кудрі вулиця
# Івана Лепсе бульвар
# Івана Мазепи вулиця
# Івана Мар’яненка провулок
# Івана Миколайчука вулиця
# Івана Неходи вулиця
# Івана Огієнка вулиця
# Івана Пулюя вулиця
# Івана Піддубного вулиця
# Івана Світличного вулиця
# Івана Сергієнка вулиця
# Івана Сірка вулиця
# Івана Федорова вулиця
# Івана Франка вулиця
# Івана Франка площа
# Івана Шевцова вулиця
# Іванівський тупик
# Ігоря Завірюхіна вулиця
# Ігоря Качуровського провулок
# Ігоря Турчина вулиця
# Ігоря Шамо бульвар
# Ігорєва вулиця
# Ігорівська вулиця
# Іжевська вулиця
# Ізюмська вулиця
# Іллінська вулиця
# Індустріальна вулиця
# Інженера Бородіна вулиця
# Інженерна вулиця
# Інженерний провулок
# Інститутська вулиця
# Іоана Павла II вулиця
# Іпсилантієвський провулок
# Ірининська вулиця
# Іркутська вулиця
# Ірпінська вулиця
# Ісаакяна вулиця
# Іскрівська вулиця
# Абрикосова вулиця
# Автодорожная улица
# Автозаводська вулиця
# Автошляхова вулиця
# Авіаконструктора Ігоря Сікорського вулиця
# Авіаконструктора Антонова вулиця
# Авіаторів вулиця
# Агрегатна вулиця
# Агрономічна вулиця
# Адама Міцкевича вулиця
# Аеродромна вулиця
# Азербайджанська вулиця
# Азовська вулиця
# Айвазовського провулок
# Академіка Єфремова вулиця
# Академіка Амосова вулиця
# Академіка Богомольця вулиця
# Академіка Булаховського вулиця
# Братів Гавришів вулиця
# Братів Зерових вулиця
# Брест-Литовське шосе
# Брест-Литовський провулок
# Броварська вулиця
# Броварський проспект
# Броварської Сотні вулиця
# Брусилівська вулиця
# Брюллова вулиця
# Бударіна вулиця
# Будаївська вулиця
# Буденного переулок
# Будищанська вулиця
# Будьонного вулиця
# Будівельна вулиця
# Будівельників вулиця
# Будівельників провулок
# Будіндустрії вулиця
# Булгакова вулиця
# Бульварна вулиця
# Бульварно-Кудрявська вулиця
# Бурденка провулок
# Бурки ул
# Буслівська вулиця
# Бутишев провулок
# Бучанська вулиця
# Бучанське шосе
# Білгородська вулиця
# Білицька вулиця
# Біличанська вулиця
# Білогородська вулиця
# Білогородський провулок
# Білогородський тупик
# Біломорська вулиця
# Білоруська вулиця
# Білоцерківська вулиця
# В.Лобановского
# В.Непопа
# Вавилових вулиця
# Вадима Гетьмана вулиця
# Вакуленчука вулиця
# Валентина Сєрова вулиця
# Валерія Лобановського вулиця
# Валерія Лобановського проспект
# Валківська вулиця
# Валі Котика вулиця
# Ванди Василевської вулиця
# Варшавская
# Варшавська
# Васильковская улица
# Васильківська вулиця
# Васильківський провулок
# Васильченка вулиця
# Василя Вишиваного вулиця
# Василя Дончука вулиця
# Василя Жуковського вулиця
# Василя Жуковського провулок
# Василя Касіяна вулиця
# Василя Кучера вулиця
# Василя Порика вулиця
# Василя Симоненка вулиця
# Василя Стуса вулиця
# Василя Сурікова вулиця
# Василя Чумака вулиця
# Ватутіна вулиця
# Введенська вулиця
# Велика Васильківська вулиця
# Велика Житомирська вулиця
# Велика Китаївська вулиця
# Велика Кільцева вулиця
# Велика Лугова вулиця
# Великого Жовтня вулиця
# Вербицького вулиця
# Вереснева вулиця
# Верхньоключова вулиця
# Верхня вулиця
# Верхній Вал вулиця
# Верховинна вулиця
# Верховної Ради бульвар
# Весильна
# Виборзька вулиця
# Виговського вулиця
# Вигурівський бульвар
# Визволителів вулиця
# Визволителів проспект
# Виставкова вулиця
# Вишгородська вулиця
# Вишнева вулиця
# Вишневий провулок
# Вишняківська вулиця
# Водопровідна вулиця
# Военные городок  №11
# Военный городок
# Военный городок 11
# Военный городок №11
# Воздвиженська вулиця
# Возз’єднання вулиця
# Вознесенський узвіз
# Вокзальна вулиця
# Вокзальна площа
# Вокзальний провулок
# Волго-Донська вулиця
# Волгоградська вулиця
# Волзька вулиця
# Волинська вулиця
# Волинський провулок
# Володимира Великого вулиця
# Володимира Винниченка вулиця
# Володимира Маяковського проспект
# Володимира Момота вулиця
# Володимира Наумовича вулиця
# Володимира Покотила вулиця
# Володимира Савченка вулиця
# Володимира Сосюри вулиця
# Володимира Чаплінського вулиця
# Володимиро-Либідська вулиця
# Володимирська вулиця
# Володимирський узвіз
# Володі Дубініна вулиця
# Волоська вулиця
# Волошкова вулиця
# Волховська вулиця
# Ворошилова вулиця
# Воскресенська вулиця
# Восьмого Березня вулиця
# Воїнів-інтернаціоналістів вулиця
# Врубелівський узвіз
# Всеволода Нестайка вулиця
# Вузівська вулиця
# Вулиця Петлюри
# Відпочинку вулиця
# Відрадна вулиця
# Відрадний проспект
# Військове містечко №11
# Вікентія Беретті вулиця
# Вікентія Хвойки вулиця
# Віктора Забіли вулиця
# Віктора Йови вулиця
# Вільгельма Котарбінського вулиця
# Вільшанська вулиця
# Вінницька вулиця
# Вірменська вулиця
# Віскозна вулиця
# Вітавська вулиця
# Віто-Литовський провулок
# Вітряного вулиця
# Вітряні Гори вулиця
# Вітянська вулиця
# В’ячеслава Липинського вулиця
# В’ячеслава Чорновола вулиця
# Г. Сковороди
# Г.Сковороди
# Гагаріна вулиця
# Газова вулиця
# Гайдара вулиця
# Гайдая вулиця
# Галицька вулиця
# Гарматна вулиця
# Гарматний провулок
# Гаршина вулиця
# Гвардійська вулиця
# Гельсінської Групи вулиця
# Генерала Алмазова вулиця
# Генерала Ватутіна проспект
# Генерала Вітрука вулиця
# Генерала Жмаченка вулиця
# Генерала Наумова вулиця
# Генерала Потапова вулиця
# Генерала Родимцева вулиця
# Генерала Тупикова вулиця
# Геологів вулиця
# Георгія Гонгадзе проспект
# Георгія Кірпи вулиця
# Георгія Тороповського вулиця
# Героїв
# Героїв Бреста площа
# Героїв Дніпра
# Героїв Дніпра вулиця
# Героїв Космосу вулиця
# Героїв Майдану вулиця
# Героїв Майдану провулок
# Героїв Небесної Сотні алея
# Героїв Небесної Сотні вулиця
# Героїв Оборони вулиця
# Героїв Севастополя вулиця
# Героїв Сталінграда проспект
# Героїв Трипілля вулиця
# Героїв УПА вулиця
# Герцена вулиця
# Глазунова вулиця
# Глибоцька вулиця
# Глибочицька вулиця
# Глібова вулиця
# Глінки вулиця
# Гната Хоткевича вулиця
# Гната Хоткевича провулок
# Гната Юри вулиця
# Гнатюка провулок
# Гоголя вулиця
# Гоголівська вулиця
# Головатого вулиця
# Головачова вулиця
# Голосіївська вулиця
# Голосіївський провулок
# Голосіївський проспект
# Голуба Аркадия
# Гомельська вулиця
# Гомельський провулок
# Гончарна вулиця
# Горбатюка вулиця
# Горлівська вулиця
# Горького вулиця
# Горького провулок
# Горького улица
# Госпітальна вулиця
# Госпітальний провулок
# Гостомельське шосе
# Гостомельське шоссе
# Градинська
# Градинська вулиця
# Грибна вулиця
# Грибоєдова вулиця
# Григоровича-Барського вулиця
# Григорія Андрющенка вулиця
# Григорія Ващенка вулиця
# Григорія Онискевича вулиця
# Григорія Сковороди вулиця
# Григорія Царика вулиця
# Гродненська вулиця
# Громова вулиця
# Грушева вулиця
# Грушевського вулиця
# Гусовського вулиця
# Гіллястий провулок
# Давидчука вулиця
# Далека вулиця
# Данила Щербаківського вулиця
# Дарвіна вулиця
# Дарницька площа
# Дарницький бульвар
# Дарничанка вулиця
# Дачна вулиця
# Дашавська вулиця
# Двінська вулиця
# Дегтярівська вулиця
# Дежньова вулиця
# Декабристов улица
# Декабристів вулиця
# Деміївська вулиця
# Деміївська площа
# Депутатська вулиця
# Деревлянська вулиця
# Деревообробна вулиця
# Деснянська вулиця
# Десятинна вулиця
# Десятинний провулок
# Джерельна вулиця
# Джерельний провулок
# Дзержинського вулиця
# Дмитра Вишневецького вулиця
# Дмитра Луценка вулиця
# Дмитра Яворницького вулиця
# Дмитра Янченка вулиця
# Дмитрівська вулиця
# Дніпрельстан вулиця
# Дніпроводська вулиця
# Дніпровська вулиця
# Дніпровська набережна
# Дніпровський проспект
# Дніпровський узвіз
# Дніпродзержинська вулиця
# Дніпропетровська вулиця
# Дністровська вулиця
# Добрий Шлях вулиця
# Добровольчих Батальйонів вулиця
# Добролюбова вулиця
# Довженка вулиця
# Довнар-Запольського вулиця
# Додохова вулиця
# Докучаєвська вулиця
# Доківська вулиця
# Долинна вулиця
# Донбасівська вулиця
# Донецька вулиця
# Дорогожицька вулиця
# Драгоманова вулиця
# Драйзера
# Дружби Народів бульвар
# Дружби вулиця
# Дружківська вулиця
# Дубенська вулиця
# Дубровицька вулиця
# Ділова вулиця
# Ежена Потьє вулиця
# Електриків вулиця
# Електриків провулок
# Електротехнічна вулиця
# Енгельса вулиця
# Енергетиків вулиця
# Ентузіастів вулиця
# Еспланадна вулиця
# Естонська вулиця
# Жамбила Жабаєва вулиця
# Желябова вулиця
# Живописна вулиця
# Жилянська вулиця
# Житньоторзька вулиця
# Житня вулиця
# Житомирське шосе
# Житомирський провулок
# Жмеринська вулиця
# Жовтнева вулиця
# Жовтневий провулок
# Жовтневої Революції вулиця
# Жолудєва вулиця
# Жуковського вулиця
# Жулянська вулиця
# Завальна вулиця
# Заводська вулиця
# Заводський провулок
# Завокзальна вулиця
# Загородня вулиця
# Загородняя улица
# Загребля вулиця
# Задорожний провулок
# Залізнична вулиця
# Залізничне шосе
# Замковецька вулиця
# Заміська вулиця
# Заньковецької вулиця
# Западинська вулиця
# Запорізька вулиця
# Заречная улица
# Зарічна вулиця
# Зарічний провулок
# Затишна вулиця
# Затишний провулок
# Західний провулок
# Звіринецька вулиця
# Зв’язку вулиця
# Зв’язківців вулиця
# Здолбунівська вулиця
# Зелена вулиця
# Зелений провулок
# Зелений тупик
# Зеленогірська вулиця
# Златопільська вулиця
# Зодчих вулиця
# Золотоворітська
# Золотоворітська вулиця
# Золотоворітський проїзд
# Золотоустівська вулиця
# Золочівський провулок
# Зоологічна вулиця
# Зоряна вулиця
# Зоряний провулок
# Зої Гайдай вулиця
# Зої Космодем’янської вулиця
# Зрошувальна вулиця
# Ивана Франка улица
# Йорданська вулиця
# Кавказька вулиця
# Кавказький провулок
# Кадетський Гай вулиця
# Казанська вулиця
# Казимира Малевича вулиця
# Кайсарова вулиця
# Калачівська вулиця
# Калинова вулиця
# Калініна вулиця
# Каменярів вулиця
# Кам’янець-Подільська вулиця
# Капітальна вулиця
# Карельський провулок
# Карла Лібкнехта вулиця
# Карла Маркса вулиця
# Карла Маркса улица
# Кармелюка вулиця
# Карьерная
# Кар’єрна вулиця
# Катерини Білокур вулиця
# Каунаська вулиця
# Каширіна вулиця
# Каштанова вулиця
# Квітки Цісик вулиця
# Квітки-Основ’яненка вулиця
# Квіткова вулиця
# Квітковий провулок
# Квітневий провулок
# Квітучий провулок
# Керамічна вулиця
# Керамічний провулок
# Керченська вулиця
# Киевская улица
# Кирило-Мефодіївська вулиця
# Кирилівська вулиця
# Кирпоноса вулиця
# Китаївська вулиця
# Киянівський провулок
# Києво-Мироцька вулиця
# Київська вулиця
# Київський Шлях вулиця
# Київський провулок
# Клавдіївська вулиця
# Клеманська вулиця
# Кленова (Леніна) вулиця
# Кловський узвіз
# Княгині Ольги вулиця
# Княжий Затон вулиця
# Князя Святослава вулиця
# Кобзарський провулок
# Ковальський провулок
# Ковпака вулиця
# Ковшевацкого
# Ковшевацкого ул
# Кожум’яцька вулиця
# Козацька вулиця
# Колгоспна вулиця
# Колгоспний провулок
# Колекторна вулиця
# Коломийський провулок
# Колпитська казарма урочище
# Кольцова бульвар
# Комарова
# Комарова вулиця
# Комарова переулок
# Комарова улица
# Комбайнерів вулиця
# Комбінатна вулиця
# Композитора Лятошинського вулиця
# Композитора Мейтуса вулиця
# Компресорна
# Комсомольська вулиця
# Комсомольців 20-х років вулиця
# Комінтерну вулиця
# Коноплянська вулиця
# Контрактова площа
# Кооперативна вулиця
# Коперника вулиця
# Копилівська вулиця
# Корабельна вулиця
# Короленка вулиця
# Короленківська вулиця
# Коротка вулиця
# Космонавта Волкова вулиця
# Космонавта Комарова проспект
# Космонавтів вулиця
# Космічна вулиця
# Косогірний провулок
# Костьольна вулиця
# Костя Гордієнка провулок
# Костянтина Данькевича вулиця
# Костянтина Заслонова вулиця
# Костянтинівська вулиця
# Котляревського вулиця
# Котовского
# Котовського
# Котовського вулиця
# Коцюбинського вулиця
# Кочагіна провулок
# Кошевацкого улица
# Кошова
# Кошового вулиця
# Крайня вулиця
# Краківська вулиця
# Красилівська вулиця
# Краснодарська вулиця
# Краснокутський провулок
# Кривова вулиця
# Криворізький провулок
# Крилова вулиця
# Кримська вулиця
# Кримський провулок
# Кринична вулиця
# Кришталева вулиця
# Кронштадтська вулиця
# Кропивницького вулиця
# Круглоуніверситетська вулиця
# Крупської вулиця
# Крутий узвіз
# Кудрявська вулиця
# Кудрявський узвіз
# Кудряшова вулиця
# Куйбышева улица
# Кулібіна вулиця
# Купріна вулиця
# Курганівський провулок
# Кургузова вулиця
# Куренівська вулиця
# Куренівський провулок
# Курнатовського вулиця
# Курська вулиця
# Кустанайська вулиця
# Кіквідзе вулиця
# Кільцева вулиця
# Кільцева дорога
# Кіото вулиця
# Кірова вулиця
# Кіровоградська вулиця
# Кітченка вулиця
# Лабораторна вулиця
# Лабораторний провулок
# Лаврська вулиця
# Лагерна вулиця
# Лариси Руденко вулиця
# Лебединська вулиця
# Лебедєва-Кумача вулиця
# Левандовська вулиця
# Леваневського вулиця
# Левка Ревуцького вулиця
# Левітана вулиця
# Лейпцизька вулиця
# Лейтенанта Кибенка вулиця
# Ленина улица
# Ленинградская
# Леніна
# Леніна вулиця
# Ленінградська
# Ленінградська вулиця
# Леонтовича вулиця
# Леоніда Бикова бульвар
# Леоніда Первомайського вулиця
# Лермонтова вулиця
# Лес
#
# Леси Украинки переулок
# Леся Курбаса проспект
# Лесі Українки бульвар
# Лесі Українки вулиця
# Леха Качинського вулиця
# Ливарська вулиця
# Липська вулиця
# Лисенка вулиця
# Лисогірська вулиця
# Лисогірський провулок
# Лисянська вулиця
# Личака вулиця
# Лобановського вулиця
# Лобачевського вулиця
# Лобачевського провулок
# Локомотивна вулиця
# Ломоносова
# Ломоносова вулиця
# Ломоносова провулок
# Лохвицька вулиця
# Лугова вулиця
# Лук’янівська вулиця
# Лук’янівський провулок
# Луначарського вулиця
# Лучистая
# Льва Толстого вулиця
# Львівська вулиця
# Львівська площа
# Лютеранська вулиця
# Лютнева
# Лєскова вулиця
# Лікарняна вулиця
# Лікарняний провулок
# Лінійна вулиця
# Лісківська вулиця
# Лісна вулиця
# Лісний провулок
# Ліснича вулиця
# Лісова вулиця
# Лісовий провулок
# Лісовий проспект
# Лісозахисний провулок
# М.Хвильового
# Магнітогорська вулиця
# Магнітогорський провулок
# Магістральна вулиця
# Мазепи вулиця
# Мазепи проспект
# Майкопський провулок
# Макаренка вулиця
# Максима Берлінського вулиця
# Максима Кривоноса вулиця
# Максименка вулиця
# Макіївська вулиця
# Макіївський провулок
# Мала Житомирська вулиця
# Мала Кільцева вулиця
# Малий провулок
# Малиновського вулиця
# Малинська вулиця
# Малишка вулиця
# Малишка провулок
# Малоземельна вулиця
# Малокитаївська вулиця
# Малокиївська вулиця
# Малопідвальна вулиця
# Мальовнича вулиця
# Мальовничий провулок
# Маміна-Сибірякова вулиця
# Марганецька вулиця
# Марини Цвєтаєвої вулиця
# Маричанська вулиця
# Марка Безручка вулиця
# Марка Вовчка вулиця
# Мартиросяна вулиця
# Маршака вулиця
# Маршака провулок
# Маршала Гречка вулиця
# Маршала Жукова вулиця
# Маршала Конєва вулиця
# Маршала Красовського вулиця
# Маршала Малиновського вулиця
# Маршала Рибалка вулиця
# Маршала Рокосовського проспект
# Маршала Тимошенка вулиця
# Маршала Якубовського вулиця
# Марії Лагунової вулиця
# Марії Приймаченко бульвар
# Матросова вулиця
# Матросова провулок
# Машинобудівна вулиця
# Машинобудівний провулок
# Машинобудівників вулиця
# Маяковського
# Маяковського вулиця
# Меблева вулиця
# Медова вулиця
# Межигірська вулиця
# Межова вулиця
# Межовий провулок
# Мельника провулок
# Мельникова вулиця
# Металургів вулиця
# Металістів вулиця
# Металістів провулок
# Метробудівська вулиця
# Метрологічна вулиця
# Механізаторів вулиця
# Мечникова вулиця
# Микильський провулок
# Миколаївська вулиця
# Миколи Амосова вулиця
# Миколи Бажана проспект
# Миколи Василенка вулиця
# Миколи Гастелло вулиця
# Миколи Грінченка вулиця
# Миколи Гулака вулиця
# Миколи Закревського вулиця
# Миколи Кибальчича вулиця
# Миколи Краснова вулиця
# Миколи Лаврухіна вулиця
# Миколи Лебедєва вулиця
# Миколи Матеюка вулиця
# Миколи Мурашка вулиця
# Миколи Пимоненка вулиця
# Миколи Раєвського вулиця
# Миколи Садовського провулок
# Миколи Ушакова вулиця
# Миколи Шепелєва вулиця
# Миколи Шпака вулиця
# Миколи Юнкерова вулиця
# Микільсько-Ботанічна вулиця
# Микільсько-Слобідська вулиця
# Милославська вулиця
# Миронівська вулиця
# Миропільська вулиця
# Миру вулиця
# Миру проспект
# Митрополита Андрея Шептицького вулиця
# Митрополита Василя Липківського вулиця
# Митрополита Володимира Сабодана вулиця
# Михаила Грушевского
# Михайла Брайчевського вулиця
# Михайла Гришка вулиця
# Михайла Грушевського вулиця
# Михайла Донця вулиця
# Михайла Драгомирова вулиця
# Михайла Калмикова вулиця
# Михайла Котельникова вулиця
# Михайла Коцюбинського вулиця
# Михайла Максимовича вулиця
# Михайла Мишина вулиця
# Михайла Омеляновича-Павленка вулиця
# Михайла Стельмаха вулиця
# Михайлівська
# Михайлівська вулиця
# Михайлівська площа
# Михайлівський провулок
# Мичурина улица
# Мичуринские Дачи
# Молдавська вулиця
# Молодогвардійська вулиця
# Молодіжна вулиця
# Молодіжна вулиця;Лінійна вулиця
# Монтажників вулиця
# Моринецька вулиця
# Москаленко
# Москвіна вулиця
# Московська вулиця
# Московська площа
# Московський провулок
# Мостицька вулиця
# Мостова вулиця
# Моторна вулиця
# Моторний провулок
# Моїсеєва вулиця
# Музейний провулок
# Музиченка вулиця
# Мукачівська вулиця
# Мурманська вулиця
# Муромська вулиця
# Мілютенка вулиця
# Мінеральна вулиця
# Мінська вулиця
# Мінське шосе
# Мінський провулок
# Мінський проспект
# Мініна вулиця
# Міста Шалетт вулиця
# Міська вулиця
# Мічуріна вулиця
# Набережна вулиця
# Набережная
# Набережний тупик
# Набережно-Корчуватська вулиця
# Набережно-Лугова вулиця
# Набережно-Печерська дорога
# Набережно-Хрещатицька вулиця
# Нагірна вулиця
# Наддніпрянське шосе
# Над’ярна вулиця
# Назарівська вулиця
# Народна вулиця
# Народная
# Народная улица
# Народний провулок
# Народного Ополчення вулиця
# Народовольцев пер
# Наталії Ужвій вулиця
# Науки проспект
# Нахимова
# Нахимова переулок
# Нахімова вулиця
# Невська вулиця
# Незалежності бульвар
# Незалежності вулиця
# Некрасова вулиця
# Некрасовська вулиця
# Немировича-Данченка вулиця
# Несторівський провулок
# Нижньоюрківська вулиця
# Нижній Вал вулиця
# Нова
# Нова вулиця
# Новаторів вулиця
# Новгородська вулиця
# Нове Шосе вулиця
# Новий Шлях вулиця
# Новикова-Прибоя вулиця
# Новобогданівська вулиця
# Нововокзальна вулиця
# Новогоспітальна вулиця
# Новодарницька вулиця
# Новозабарська вулиця
# Новокостянтинівська вулиця
# Новомостицька вулиця
# Новообуховское шоссе 1
# Новопечерський провулок
# Новопирогівська вулиця
# Новопольова вулиця
# Новопромислова вулиця
# Новопрорізна вулиця
# Новоукраїнська вулиця
# Ніжинська вулиця
# Німецька вулиця
# Оболонська Набережна вулиця
# Оболонська вулиця
# Оболонська площа
# Оболонський проспект
# Обсерваторна вулиця
# Обухівська вулиця
# Объездная дорога
# Ованеса Туманяна вулиця
# Овруцька вулиця
# Одеська вулиця
# Покровська
# Покровська вулиця
# Полевая
# Полевая улица
# Ползунова вулиця
# Полкова вулиця
# Полковий провулок
# Полковника Затєвахіна вулиця
# Полковника Потєхіна вулиця
# Полковника Шутова вулиця
# Половецька вулиця
# Полтавська вулиця
# Полтавський провулок
# Полуничная улица
# Польова вулиця
# Польовий провулок
# Полянська вулиця
# Полярна вулиця
# Поліська вулиця
# Поліський провулок
# Політехнічна вулиця
# Політехнічний провулок
# Помаранчева вулиця
# Пономарьова вулиця
# Попова вулиця
# Поповича вулиця
# Попудренка вулиця
# Попільнянська вулиця
# Пост-Волинська вулиця
# Постова вулиця
# Почайнинська вулиця
# Поштова пл.
# Поштова площа
# Поштовий провулок
# Правди проспект
# Празька вулиця
# Праці бульвар
# Предславинська вулиця
# Преображенська вулиця
# Привокзальна вулиця
# Привокзальна пл.
# Привокзальна площа
# Прикордонна
# Прилужна вулиця
# Прилуцька вулиця
# Приміський провулок
# Приозерна вулиця
# Прип’ятська вулиця
# Прирічна вулиця
# Притисько-Микільська вулиця
# Причальна вулиця
# Провіантська вулиця
# Проектна вулиця
# Проектована вулиця
# Пролетарська вулиця
# Пролетарський провулок
# Пролісок вулиця
# Промислова вулиця
# Прорізна вулиця
# Проскурівська вулиця
# Протасів Яр вулиця
# Професора Підвисоцького вулиця
# Пріорська вулиця
# Пугачова вулиця
# Путивльська вулиця
# Путрівська вулиця
# Пухівська вулиця
# Пушкіна вулиця
# Пушкіна провулок
# Пушкінська вулиця
# Пшенична вулиця
# Південна вулиця
# Південно-Західна вулиця
# Північна вулиця
# Північно-Сирецька вулиця
# Підгірна вулиця
# Підлипка вулиця
# Підлісна вулиця
# Піонерська вулиця
# Пітерська вулиця
# Піщана вулиця
# П’ятигорський провулок
# Радомишльська вулиця
# Радосинська вулиця
# Радунська вулиця
# Радянська вулиця
# Радіальна вулиця
# Райдужна вулиця
# Ракетна вулиця
# Раменська вулиця
# Ранкова вулиця
# Раїси Окіпної вулиця
# Ревуцького вулиця
# Регенераторна вулиця
# Редутна вулиця
# Рейтарська вулиця
# Рекунова площа
# Рибальська вулиця
# Риболовецька вулиця
# Ризька вулиця
# Рильський провулок
# Рилєєва вулиця
# Римського-Корсакова вулиця
# Робкоровська вулиця
# Робочий провулок
# Робітнича вулиця
# Рогозівська вулиця
# Рожева вулиця
# Рокосовського вулиця
# Ромена Роллана бульвар
# Російська вулиця
# Рубежівський провулок
# Руднєва провулок
# Рудыковская
# Ружинська вулиця
# Ружинський провулок
# Русанівська набережна
# Русанівський бульвар
# Руслана Лужевського провулок
# Рєпіна вулиця
# Різницька вулиця
# Річковий провулок
# Річна вулиця
# С. Петлюри
# Сабурова вулиця
# Сагайдачного
# Садова вулиця
# Садовая улица
# Садовий провулок
# Саксаганського вулиця
# Салютна вулиця
# Самойленка вулиця
# Санаторний провулок
# Саперне Поле вулиця
# Саперно-Слобідська вулиця
# Саперно-Слобідський проїзд
# Саратовська вулиця
# Сахалінська вулиця
# Сахалінський провулок
# Свободи вулиця
# Свободи проспект
# Свято-Покровська вулиця
# Святомихайлівська вулиця
# Святошинська вулиця
# Святошинська площа
# Святошинський провулок
# Святоюріївська вулиця
# Світлицького вулиця
# Світлогорська вулиця
# Севастопольська вулиця
# Севастопольська площа
# Северинівська
# Семашка вулиця
# Семена Скляренка вулиця
# Семенівська вулиця
# Сеноманський провулок
# Серафимовича вулиця
# Сергія Данченка вулиця
# Сергія Камінського вулиця
# Сергія Колоса вулиця
# Сергія Лазо вулиця
# Сергія Москаленка вулиця
# Сергія Оврашка вулиця
# Серпова вулиця
# Сиваська вулиця
# Симиренка вулиця
# Симона Петлюри вулиця
# Симоненка вулиця
# Синьоозерна вулиця
# Сирецька вулиця
# Сирецько-садова вулиця
# Склозаводська вулиця
# Славгородська вулиця
# Слави алея
# Слави вулиця
# Слобідський провулок
# Словянська
# Смоленська вулиця
# Смородинський узвіз
# Смілянська вулиця
# Соборна вулиця
# Соборний провулок
# Соборності проспект
# Солнечная улица
# Сологуба вулиця
# Соломії Крушельницької вулиця
# Солом’янська вулиця
# Солом’янська площа
# Соляна вулиця
# Сонячна вулиця
# Сормовська вулиця
# Сосницька вулиця
# Соснова вулиця
# Сосновий мікрорайон
# Сосновий провулок
# Софії Перовської вулиця
# Софіївська вулиця
# Софіївський провулок
# Соцмістечко
# Соціалістична вулиця
# Спартаківська вулиця
# Спаська вулиця
# Спортивна площа
# Спортивний провулок
# Срибнокильская, 8
# Срібнокільська вулиця
# Ставропольська вулиця
# Ставропольський провулок
# Стадіонна вулиця
# Стадіонний провулок
# Станіславського вулиця
# Старий провулок
# Старовокзальна вулиця
# Старокиевская ул.
# Старокиївська вулиця
# Старокиївський провулок
# Старонаводницька вулиця
# Старосільська вулиця
# Стельмаха
# Степана Бандери вулиця
# Степана Бандери проспект
# Степана Олійника вулиця
# Степана Руданського вулиця
# Степова вулиця
# Стеценка вулиця
# Столичне шосе
# Столичное шоссе
# Стратегічне шосе
# Стрийська вулиця
# Стрітенська вулиця
# Студентська вулиця
# Суворова вулиця
# Суздальська вулиця
# Сулеймана Стальського вулиця
# Сумська вулиця
# Сумський провулок
# Східна вулиця
# Сєдова вулиця
# Сєченова вулиця
# Сільгосп Технікум вулиця
# Сількорівська вулиця
# Сільська вулиця
# Сільськогосподарський провулок
# Сімферопольська вулиця
# Сім’ї Кульженків вулиця
# Сім’ї Сосніних вулиця
# Сім’ї Стешенків вулиця
# Сім’ї Хохлових вулиця
# Січневого Повстання вулиця
# Січових Стрільців
# Січових Стрільців вулиця
# Таврійська вулиця
# Тампере вулиця
# Тараса Шевченка
# Тараса Шевченка бульвар
# Тараса Шевченка вулиця
# Тараса Шевченка площа
# Тараса Шевченка провулок
# Тарасівська вулиця
# Тарасівський провулок
# Таращанська вулиця
# Татарська вулиця
# Тбіліський провулок
# Тверська вулиця
# Тверський тупик
# Телеграфний провулок
# Теодора Драйзера вулиця
# Теплична вулиця
# Тепловозна вулиця
# Теремківська вулиця
# Терешкової провулок
# Терещенківська вулиця
# Тернопольская
# Теслярська вулиця
# Технікумівська
# Технікумівська, 1
# Тешебаєва вулиця
# Тимофія Шамрила вулиця
# Тимірязєвська вулиця
# Тираспільська вулиця
# Титова вулиця
# Тихий провулок
# Толбухіна вулиця
# Толбухіна провулок
# Толстого вулиця
# Томашпільська вулиця
# Травнева вулиця
# Травневий провулок
# Тракторна вулиця
# Тракторний провулок
# Траншейна вулиця
# Тропініна вулиця
# Тропініна провулок
# Тростянецька вулиця
# Трояндова вулиця
# Трудова вулиця
# Труханівська вулиця
# Трьохсвятительська вулиця
# Тулузи вулиця
# Тульчинська вулиця
# Тургенєва вулиця
# Тургенєвська вулиця
# Турівська вулиця
# Тіниста
# Ужгородська вулиця
# Українська вулиця
# Уманська вулиця
# Університетська вулиця
# Уральська вулиця
# Урицького вулиця
# Урлівська вулиця
# Урожайна вулиця
# Успішна вулиця
# Уссурійська вулиця
# Уссурійський провулок
# Учительський провулок
# Ушакова вулиця
# Ушинського вулиця
# Федора Ернста вулиця
# Федора Кричевського вулиця
# Федора Максименка вулиця
# Фельдмана вулиця
# Феодори Пушиної вулиця
# Феодосійська вулиця
# Феодосійський провулок
# Фестивальна вулиця
# Фестивальний провулок
# Флоренції вулиця
# Франка вулиця
# Френкеля вулиця
# Фролівська вулиця
# Фрунзе вулиця
# Фурманова вулиця
# Фізкультури вулиця
# Харківське шосе
# Херсонська вулиця
# Хлеборобная улица
# Хмельницька вулиця
# Хмельницького вулиця
# Холмогорський провулок
# Хорива вулиця
# Хорольська вулиця
# Хрестовий провулок
# Хрещатик вулиця
# Хутоярівський провулок
# Центральна вулиця
# Центральная(Ленина)
# Центрально-Садова вулиця
# Центральної Ради вулиця
# Цитадельна вулиця
# Чабанівська вулиця
# Чапаєва вулиця
# Чаплигіна провулок
# Чекістів вулиця
# Челюскінців вулиця
# Челябінська вулиця
# Червоноармійська вулиця
# Червоноармійський провулок
# Червоного Орача
# Червонозаводський провулок
# Червонопільська вулиця
# Червоноткацька вулиця
# Черешнева вулиця
# Черкасская
# Черкаська вулиця
# Чернишевського вулиця
# Черняховського вулиця
# Черняхівського вулиця
# Чернівецька вулиця
# Чернігівська вулиця
# Чехова вулиця
# Чеховський провулок
# Чигиринський провулок
# Чигоріна вулиця
# Чистяківська вулиця
# Чкалова вулиця
# Чмилів провулок
# Чоколівський бульвар
# Чоповського вулиця
# Чорнобильська вулиця
# Чубаря вулиця
# Чубинского 1
# Чугуївський провулок
# Чумацька вулиця
# Шахтарська вулиця
# Шевченка
# Шевченка бульвар
# Шевченка вулиця
# Шевченка площа
# Шевченка проспект
# Шепетівська вулиця
# Школьная ул.
# Шкільна вулиця
# Шовковична вулиця
# Шовкуненка вулиця
# Шолом-Алейхема вулиця
# Шолуденка вулиця
# Шота Руставелі вулиця
# Шулявська вулиця
# Щаслива вулиця
# Щекавицька вулиця
# Щолківська вулиця
# Щорса вулиця
# Щусєва вулиця
# Юліуса Фучика вулиця
# Юних Комунарів вулиця
# Юності вулиця
# Юрківська вулиця
# Юрія Гагаріна вулиця
# Юрія Гагаріна проспект
# Юрія Кондратюка вулиця
# Юрія Пасхаліна вулиця
# Юрія Смолича вулиця
# Юрія Шумського вулиця
# Яблунева вулиця
# Яблуневий мікрорайон
# Яблунська
# Яблунська вулиця
# Яблунський провулок
# Ягідна вулиця
# Якова Качури вулиця
# Якуба Коласа вулиця
# Ялинкова вулиця
# Ялтинська вулиця
# Ямська вулиця
# Яна Райніса вулиця
# Янтарна вулиця
# Януша Корчака вулиця
# Ярова вулиця/Петропавлівська
# Яровая улица
# Ярослава Івашкевича вулиця
# Ярослава Гашека бульвар
# Ярослава Мудрого вулиця
# Ярославська вулиця
# Ярославський провулок
# Ярославів Вал вулиця
# Ясна вулиця
# Ясногірська вулиця
# Яснополянська вулиця
# вул Марка Вовчка
# вул. Велика Кільцева
# вул. Дзержинського
# вул. Дімітрова
# вул. Лісова (ул. Лесная)
# вулиця 2-га Садова
# вулиця Академіка Заболотного
# вулиця Академічна
# вулиця Артема
# вулиця Багірова
# вулиця Березова
# вулиця Виставкова
# вулиця Вітянська
# вулиця Героїв Майдану
# вулиця Київська
# вулиця Леніна
# вулиця Лисенка
# вулиця Лугова
# вулиця Озерна
# вулиця Червоноармійська
# вулиця Шевченка
# гоголя
# киллометр
# лютнева
# майдан Незалежності
# площа Паширова
# прикордонна
# провулок Заміський
# провулок Колгоспний
# провулок Лісовий
# проспект Академіка Глушкова
# проспект Героев Сталинграда
# ул. Набережно-Корчеватская
# ул. Обуховское шоссе-2
# ул. Электротехническая
# ул.Дзержинского
# улица Лебединская
# шевченка
# Ґалаґанівська вулиця

# %% [markdown]
# In the section below we retrieve the data from OSM, clean up, put in CSV and then import into SQL.

# %%
OSM_PATH = "kyiv_ukraine.osm"

# %%
NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'((\w|_)+):((\w|_)+:?.*)')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
import Schema
SCHEMA = Schema.schema

# %%
# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    if element.tag == 'node':
        for i in node_attr_fields:
            if i in element.attrib.keys():
                node_attribs[i] = element.attrib[i]
            else:
                # creating a placeholder ID and user name for the one missing uid / user name entry 
                node_attribs[i] = 111111
        for j in element.iter('tag'):
            prob = PROBLEMCHARS.search(j.attrib['k'])
            colon = LOWER_COLON.search(j.attrib['k'])
            if prob:
                pass
            elif colon:
                d = {'id':element.attrib['id']}
                d['key'] = colon.group(3)
                d['type'] = colon.group(1)
                if j.attrib['k'] == 'addr:street':
                    # fixing street names per previously identified issues and correction mapping 
                    d['value'] = update_name(j.attrib['v'], street_mapping)
                elif j.attrib['k'] == 'contact:phone':
                    d['value'] = standardize_phone(j.attrib['v'], phone_mapping)
                else: 
                    d['value'] = j.attrib['v']
                tags.append(d)
            else:
                d = {'id':element.attrib['id']}
                d['key'] = j.attrib['k']
                d['type'] = default_tag_type
                if j.attrib['k'] == 'phone':
                    d['value'] = standardize_phone(j.attrib['v'], phone_mapping)
                else:
                    d['value'] = j.attrib['v']
                tags.append(d)
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        for i in way_attr_fields:
            way_attribs[i] = element.attrib[i]
        for j in element.iter('tag'):
            prob = PROBLEMCHARS.search(j.attrib['k'])
            colon = LOWER_COLON.search(j.attrib['k'])
            if prob:
                pass
            elif colon:
                d = {'id':element.attrib['id']}
                d['key'] = colon.group(3)
                d['type'] = colon.group(1)
                if j.attrib['k'] == 'addr:street':
                    d['value'] = update_name(j.attrib['v'], street_mapping)
                elif j.attrib['k'] == 'contact:phone':
                    d['value'] = standardize_phone(j.attrib['v'], phone_mapping)
                else: 
                    d['value'] = j.attrib['v']
                tags.append(d)
            else:
                d = {'id':element.attrib['id']}
                d['key'] = j.attrib['k']
                d['type'] = default_tag_type
                if j.attrib['k'] == 'phone':
                    d['value'] = standardize_phone(j.attrib['v'], phone_mapping)
                else:
                    d['value'] = j.attrib['v']
                tags.append(d)
        counter = 0 
        for k in element.iter('nd'):
            d = {'id':element.attrib['id']}
            d['node_id'] = k.attrib['ref']
            d['position'] = counter
            way_nodes.append(d)
            counter += 1
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# helper function 1
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# helper function 2
def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )

# helper function 3
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# main function
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)
                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

t0 = time()
if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=False)
print time() - t0
# Out:
# 68.5272610188

# %%
# Define tables for the SQL database
nodes = '''CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT
);'''

nodes_tags = '''CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id)
);'''

ways = '''CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT
);'''

ways_tags = '''CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id)
);'''

ways_nodes = '''CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id)
);'''

# %%
# Create the SQL database
conn = sqlite3.connect('P3_project_Kyiv_submission_2.db')

# %%
# Create tables
cursor = conn.cursor()
cursor.execute(nodes)
cursor.execute(nodes_tags)
cursor.execute(ways)
cursor.execute(ways_tags)
cursor.execute(ways_nodes)
conn.commit()

# %%
t0 = time()
# Populate the database tables with data from CSVs
# Read in the csv file as a dictionary and formatting the data as a list of tuples,
# then insert the formatted data in the database table 

# populating the nodes_tags table
with open('nodes_tags.csv','rb') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['key'].decode("utf-8"), i['value'].decode("utf-8"), i['type']) for i in dr]
    
cursor.executemany("INSERT INTO nodes_tags(id, key, value,type) VALUES (?, ?, ?, ?);", to_db)
conn.commit()

# populating the ways table
with open('ways.csv','rb') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['user'].decode("utf-8"), i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]

cursor.executemany("INSERT INTO ways(id, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?);", to_db)
conn.commit()

# populating the nodes table
with open('nodes.csv','rb') as fin:
    dr = csv.DictReader(fin)
    to_db = [(i['id'], i['lat'], i['lon'], i['user'].decode("utf-8"), i['uid'], i['version'], i['changeset'], i['timestamp']) 
             for i in dr]

cursor.executemany("INSERT INTO nodes(id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?, ?, ?);", 
                   to_db)
conn.commit()

# populating the ways_tags table
with open('ways_tags.csv','rb') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['key'].decode("utf-8"), i['value'].decode("utf-8"), i['type']) for i in dr]
    
cursor.executemany("INSERT INTO ways_tags(id, key, value,type) VALUES (?, ?, ?, ?);", to_db)
conn.commit()

# populating the ways_nodes table 
with open('ways_nodes.csv','rb') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['node_id'], i['position']) for i in dr]
    
cursor.executemany("INSERT INTO ways_nodes(id, node_id, position) VALUES (?, ?, ?);", to_db)
conn.commit()

'''
cursor.execute('SELECT * FROM nodes_tags')
all_rows = cursor.fetchall()
print('1):')
pprint(all_rows[:20])
'''
print time() - t0
# Out:
# 29.0603051186

# %%
conn.close()

# %%
# Query the sql database
# Establish connection and cursor
conn = sqlite3.connect('P3_project_Kyiv.db')
cursor = conn.cursor()

# %%
# Count unique users by their IDs in both “nodes” and “ways” nodes
query = '''SELECT uid, user, COUNT(*) as num from (SELECT uid, user FROM nodes UNION ALL SELECT uid, user from ways) as united 
GROUP BY uid ORDER BY num DESC LIMIT 10;'''

cursor.execute(query)
all_rows = cursor.fetchall()
pprint(all_rows)
# Out:
# [(561414, u'Freeways_me', 160871),
#  (1676637, u'Kilkenni', 120949),
#  (371387, u'matvey_kiev_ua', 93157),
#  (440812, u'dudka', 64077),
#  (435936, u'Legioner', 49977),
#  (648633, u'kulyk', 45594),
#  (348674, u'Cabeleira', 43623),
#  (188947, u'D_i_m', 35208),
#  (353472, u'Barbos', 34878),
#  (1872841, u'1gorok', 32352)]

# %%
# Count the total number of “ways” and “nodes” attributable to the top 50 users
query = '''SELECT sum(num) FROM (SELECT uid, COUNT(*) as num from (SELECT uid FROM nodes UNION ALL SELECT uid from ways) 
as united GROUP BY uid ORDER BY num DESC LIMIT 50) as topsomany;'''

cursor.execute(query)
all_rows = cursor.fetchall()
pprint(all_rows)
# Out:
# [(1209007,)]

# %%
# Retrieve all unique types of amenities 
query = '''SELECT DISTINCT value FROM (SELECT value FROM nodes_tags WHERE key == "amenity") 
            as allamenities ORDER BY value;'''

cursor.execute(query)
all_rows = cursor.fetchall()
pprint(all_rows)
# Out:
# [(u'agency',),
#  (u'arts_centre',),
#  (u'atm',),
#  (u'bank',),
#  (u'bar',),
#  (u'bar; pub',),
#  (u'bbq',),
#  (u'beargarden',),
#  (u'beauty',),
#  (u'bench',),
#  (u'bicycle_parking',),
#  (u'bicycle_rental',),
#  (u'bicycle_repair_station',),
#  (u'biergarten',),
#  (u'boat_rental',),
#  (u'bookmaker',),
#  (u'bureau_de_change',),
#  (u'bus_station',),
#  (u'cafe',),
#  (u'car_rental',),
#  (u'car_sharing',),
#  (u'car_wash',),
#  (u'casino',),
#  (u'charging_station',),
#  (u'childcare',),
#  (u'cinema',),
#  (u'clinic',),
#  (u'clock',),
#  (u'club',),
#  (u'college',),
#  (u'community_centre',),
#  (u'compressed_air',),
#  (u'computer',),
#  (u'convenience',),
#  (u'courthouse',),
#  (u'coworking_space',),
#  (u'dentist',),
#  (u'doctors',),
#  (u'drinking_water',),
#  (u'education',),
#  (u'educational',),
#  (u'educational_institute',),
#  (u'embassy',),
#  (u'emergency_service',),
#  (u'fast_food',),
#  (u'fire_station',),
#  (u'fitness_center',),
#  (u'fitness_station',),
#  (u'food_court',),
#  (u'fountain',),
#  (u'fuel',),
#  (u'government',),
#  (u'grave_yard',),
#  (u'grocery',),
#  (u'gym',),
#  (u'hospital',),
#  (u'insurance',),
#  (u'internet_access',),
#  (u'internet_cafe',),
#  (u'kindergarten',),
#  (u'kitchen',),
#  (u'library',),
#  (u'lottery',),
#  (u'marketplace',),
#  (u'memorial',),
#  (u'nightclub',),
#  (u'office',),
#  (u'parking',),
#  (u'parking_entrance',),
#  (u'parking_space',),
#  (u'pawnbrocker',),
#  (u'pawnshop',),
#  (u'payment_terminal',),
#  (u'pet',),
#  (u'pharmacy',),
#  (u'place_of_worship',),
#  (u'police',),
#  (u'post_box',),
#  (u'post_office',),
#  (u'post_office;bank;atm',),
#  (u'printer',),
#  (u'pub',),
#  (u'public_building',),
#  (u'publisher',),
#  (u'recycling',),
#  (u'register_office',),
#  (u'rescue_station',),
#  (u'restaurant',),
#  (u'sallon',),
#  (u'sanatorium',),
#  (u'sauna',),
#  (u'school',),
#  (u'shelter',),
#  (u'shop',),
#  (u'ski_rental',),
#  (u'smoking_area',),
#  (u'social_facility',),
#  (u'stage',),
#  (u'stripclub',),
#  (u'studio',),
#  (u'substation',),
#  (u'swimming_pool',),
#  (u'taxi',),
#  (u'telephone',),
#  (u'theatre',),
#  (u'thermometer',),
#  (u'toilets',),
#  (u'tourism',),
#  (u'townhall',),
#  (u'training',),
#  (u'translation',),
#  (u'university',),
#  (u'vehicle_inspection',),
#  (u'vending_machine',),
#  (u'veterinary',),
#  (u'waste_basket',),
#  (u'waste_disposal',),
#  (u'water_point',),
#  (u'wedding',)]

# %%
# Retrieve all arts centers 
query = 'SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "arts_centre");'

cursor.execute(query)
all_rows = cursor.fetchall()
pprint(all_rows[:5])
# Out:
# [(306524501,
#   u'name',
#   u"\u0426\u0435\u043d\u0442\u0440 \u043f\u0430\u043c'\u044f\u0442\u043a\u043e\u0437\u043d\u0430\u0432\u0441\u0442\u0432\u0430",
#   u'regular'),
#  (306524501, u'amenity', u'arts_centre', u'regular'),
#  (306524501,
#   u'alt_name',
#   u'\u0413\u0430\u043b\u043b\u0435\u0440\u0435\u044f \u041b\u0430\u0432\u0440\u0430',
#   u'regular'),
#  (742273893,
#   u'name',
#   u'\u041f\u0456\u043d\u0447\u0443\u043a \u0410\u0440\u0442 \u0426\u0435\u043d\u0442\u0440',
#   u'regular'),
#  (742273893, u'email', u'info@pinchukartcentre.org', u'regular')]

# %%
conn.close()

# %% [markdown]
# I decided to run the rest of my queries through my Linux terminal, as it readily prints the unicode characters and they appear correctly in cyrilic. I document below all the queries which I ran in Linux. The commentary around and results of these queries are in the submitted pdf file.

# %% [markdown]
# SELECT id, value FROM nodes_tags WHERE key == "name" AND id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "arts_centre");
#
# SELECT COUNT (*) FROM nodes_tags WHERE key == "amenity" and value == "atm";
#
# SELECT DISTINCT value FROM nodes_tags WHERE key == "operator" AND id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "atm") ORDER BY value;
#
# SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "coworking_space");
#
# SELECT id, value FROM nodes_tags WHERE key == "name" AND id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "coworking_space");
#
# SELECT COUNT (*) FROM nodes_tags WHERE key == "amenity" and value == "restaurant";
#
# SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "restaurant");
#
# SELECT id, value FROM nodes_tags WHERE key == "name" AND id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "restaurant");
#
# SELECT value, count(*) as num FROM nodes_tags WHERE key == "cuisine" AND id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "restaurant") GROUP BY value ORDER BY num DESC limit 10;
#
# SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "amenity" and value == "restaurant") AND id IN (SELECT id FROM nodestags WHERE key == "cuisine" and value IN ("georgian", "грузинская", "грузинскаякухня"));
#
# SELECT DISTINCT value FROM nodes_tags WHERE key == 'power';
#
# SELECT COUNT(*) FROM nodes_tags WHERE key == "power" and value == "generator";
#
# SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "power" and value == "generator") AND key == "source";
#
# SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "power" and value == "substation");
#
# SELECT * FROM nodes_tags WHERE id IN (SELECT id FROM nodes_tags WHERE key == "power" and value == "substation") and key == 'voltage';
#
# SELECT * FROM ways_tags WHERE id IN (SELECT id FROM ways_tags WHERE key == "phone") LIMIT 100;
#
# SELECT * FROM ways_tags WHERE id IN (SELECT id FROM ways_tags WHERE id == "4357024") LIMIT 100;
